# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Functions

# %% [markdown]
# ## Activation functions and their derivatives

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)  # Assume x is already sigmoid(x)

def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return (x > 0).astype(float)

def softmax(x):
    exp_x = np.exp(x - np.max(x, axis=1, keepdims=True))
    return exp_x / np.sum(exp_x, axis=1, keepdims=True)

# %% [markdown]
# ## Loss functions

# %%
def mean_squared_error(y_true, y_pred):
    return np.mean(np.square(y_true - y_pred))
    
""" slightly different formula """
def cross_entropy(y_true, y_pred):
    return -np.sum(y_true * np.log(y_pred + 1e-9)) / y_true.shape[0]

# %% [markdown]
# ## Main Class

# %%
class MLP:
    def __init__(self, layers, activations, input_size, output_size, init_method='standard'):
        self.layers = layers  # list of just hidden layers
        self.activations = activations  #list('sigmoid' or 'relu')
        
        self.weights = []
        self.biases = []
        
        # Initialize Weights & Biases based on slides
        layer_sizes = [input_size] + layers + [output_size]
        for i in range(len(layer_sizes) - 1):
            fan_in, fan_out = layer_sizes[i], layer_sizes[i + 1]
            if init_method == 'xavier':
                W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in)
                
            else:  # Standard initialization
                W = 0.01 * np.random.randn(fan_in, fan_out)
                
            b = np.zeros((1, fan_out))
            
            self.weights.append(W)
            self.biases.append(b)

    def forward(self, X):
        activations = [X] # matrix f(net)
        pre_activations = [] # matrix net
        
        # Hidden layers
        for i in range(len(self.weights) - 1):
            net = np.dot(activations[-1], self.weights[i]) + self.biases[i]
            pre_activations.append(net)
            if self.activations[i] == 'sigmoid':
                Output = sigmoid(net)
            elif self.activations[i] == 'relu':
                Output = relu(net)
            activations.append(Output)

        # Output layer (assume softmax for cross-entropy)
        net = np.dot(activations[-1], self.weights[-1]) + self.biases[-1]
        pre_activations.append(net)
        if self.activations[-1] == 'softmax':
            Output = softmax(net)  # Use single softmax definition
        else:
            Output = sigmoid(net) if self.activations[-1] == 'sigmoid' else relu(net)
        activations.append(Output)

        return activations, pre_activations
        
    def backward_mse(self, X, y, activations, pre_activations):
        grads = {}
        L = len(self.weights)  # Number of layers
        

        def activation_derivative(net, act_type):
            if act_type == 'sigmoid':
                return sigmoid_derivative(sigmoid(net))
            elif act_type == 'relu':
                return relu_derivative(net)
            return None 
        
        # Output layer gradient
        delta = -2 * (y- activations[-1])  # delta = -2f'(net)(dpi - OLi)
        if self.activations[-1] != 'softmax':
            delta *= activation_derivative(pre_activations[-1], self.activations[-1])
        
        # Backpropagation through all layers
        for l in range(L - 1, -1, -1):
            grads[f'dW{l}'] = np.dot(activations[l].T, delta) / X.shape[0] #dE/dW = delta L * O L-1 #delta = delta L+1
            grads[f'db{l}'] = np.sum(delta, axis=0, keepdims=True) / X.shape[0] # dE/db = delta
            
            if l > 0:  # Propagate delta to previous layer
                delta = np.dot(delta, self.weights[l].T) * activation_derivative(pre_activations[l-1], self.activations[l-1])
        
        return grads
    
    def backward_crossentropy(self, X, y, activations, pre_activations):
        grads = {}
        L = len(self.weights)  # Number of layers
        
        def activation_derivative(net, act_type):
            if act_type == 'sigmoid':
                return sigmoid_derivative(sigmoid(net))
            elif act_type == 'relu':
                return relu_derivative(net)
            return None
        
        # Output layer gradient (Softmax + Cross-Entropy)
        # For softmax + cross-entropy, gradient is simply (y_pred - y)
        delta = activations[-1] - y  # Assumes last layer is softmax
        
        # Backpropagation through all layers
        for l in range(L - 1, -1, -1):
            grads[f'dW{l}'] = np.dot(activations[l].T, delta) / X.shape[0]
            grads[f'db{l}'] = np.sum(delta, axis=0, keepdims=True) / X.shape[0]
            
            if l > 0:  # Propagate delta to previous layer
                delta = np.dot(delta, self.weights[l].T) * activation_derivative(pre_activations[l-1], self.activations[l-1])
        
        return grads
    
    def update_weights(self, grads, learning_rate, optimizer, state,t=1):
        if optimizer == 'sgd':
            for i in range(len(self.weights)):
                self.weights[i] -= learning_rate * grads[f'dW{i}']
                self.biases[i] -= learning_rate * grads[f'db{i}']
        
        elif optimizer == 'adam':
            beta1, beta2, epsilon = 0.9, 0.999, 1e-7
            for i in range(len(self.weights)):
                # Weights
                state[f'mW{i}'] = beta1 * state[f'mW{i}'] + (1 - beta1) * grads[f'dW{i}']  # Momentum
                state[f'vW{i}'] = beta2 * state[f'vW{i}'] + (1 - beta2) * (grads[f'dW{i}'] ** 2)  # RMSProp
                mW_corr = state[f'mW{i}'] / (1 - beta1 ** t)  # Bias correction
                vW_corr = state[f'vW{i}'] / (1 - beta2 ** t)  # Bias correction
                self.weights[i] -= learning_rate * mW_corr / (np.sqrt(vW_corr) + epsilon)
                # Biases (fixed)
                state[f'mb{i}'] = beta1 * state[f'mb{i}'] + (1 - beta1) * grads[f'db{i}']
                state[f'vb{i}'] = beta2 * state[f'vb{i}'] + (1 - beta2) * (grads[f'db{i}'] ** 2)
                mb_corr = state[f'mb{i}'] / (1 - beta1 ** t)
                vb_corr = state[f'vb{i}'] / (1 - beta2 ** t)
                self.biases[i] -= learning_rate * mb_corr / (np.sqrt(vb_corr) + epsilon)
        
        elif optimizer == 'nesterov':
            momentum = 0.9
            for i in range(len(self.weights)):
                # Weights
                velocity_w = state.get(f'vW{i}', np.zeros_like(self.weights[i]))
                prev_velocity_w = velocity_w.copy()
                velocity_w = momentum * velocity_w - learning_rate * grads[f'dW{i}']
                self.weights[i] += -momentum * prev_velocity_w + (1 + momentum) * velocity_w
                state[f'vW{i}'] = velocity_w
                # Biases
                velocity_b = state.get(f'vb{i}', np.zeros_like(self.biases[i]))
                prev_velocity_b = velocity_b.copy()
                velocity_b = momentum * velocity_b - learning_rate * grads[f'db{i}']
                self.biases[i] += -momentum * prev_velocity_b + (1 + momentum) * velocity_b
                state[f'vb{i}'] = velocity_b
        
        elif optimizer == 'adagrad':
            epsilon = 1e-7
            for i in range(len(self.weights)):
                # Weights
                state[f'vW{i}'] = state.get(f'vW{i}', np.zeros_like(self.weights[i]))
                state[f'vW{i}'] += grads[f'dW{i}'] ** 2  # Cumulative squared gradients
                self.weights[i] -= learning_rate * grads[f'dW{i}'] / (np.sqrt(state[f'vW{i}']) + epsilon)
                # Biases
                state[f'vb{i}'] = state.get(f'vb{i}', np.zeros_like(self.biases[i]))
                state[f'vb{i}'] += grads[f'db{i}'] ** 2
                self.biases[i] -= learning_rate * grads[f'db{i}'] / (np.sqrt(state[f'vb{i}']) + epsilon)
    
        elif optimizer == 'rmsprop':
            decay_rate, epsilon = 0.9, 1e-7
            for i in range(len(self.weights)):
                # Weights
                state[f'vW{i}'] = state.get(f'vW{i}', np.zeros_like(self.weights[i]))
                state[f'vW{i}'] = decay_rate * state[f'vW{i}'] + (1 - decay_rate) * (grads[f'dW{i}'] ** 2)
                self.weights[i] -= learning_rate * grads[f'dW{i}'] / (np.sqrt(state[f'vW{i}']) + epsilon)
                # Biases
                state[f'vb{i}'] = state.get(f'vb{i}', np.zeros_like(self.biases[i]))
                state[f'vb{i}'] = decay_rate * state[f'vb{i}'] + (1 - decay_rate) * (grads[f'db{i}'] ** 2)
                self.biases[i] -= learning_rate * grads[f'db{i}'] / (np.sqrt(state[f'vb{i}']) + epsilon)
                

    def train(self, X_train, y_train, X_val, y_val, epochs, batch_size, learning_rate, optimizer='sgd',loss="MSE"):
        state = {f'mW{i}': np.zeros_like(W) for i, W in enumerate(self.weights)}
        state.update({f'vW{i}': np.zeros_like(W) for i, W in enumerate(self.weights)})
        state.update({f'mb{i}': np.zeros_like(b) for i, b in enumerate(self.biases)})
        state.update({f'vb{i}': np.zeros_like(b) for i, b in enumerate(self.biases)})

        self.train_losses = []  # Store training losses
        self.val_losses = []    # Store validation losses
        
        best_val_loss = float('inf')
        patience_counter = 0
        t = 0
        for epoch in range(epochs):
            # Shuffle training data
            indices = np.random.permutation(X_train.shape[0])
            X_train, y_train = X_train[indices], y_train[indices]
            epoch_train_loss = 0
            for i in range(0, X_train.shape[0], batch_size):
                X_batch = X_train[i:i+batch_size]
                y_batch = y_train[i:i+batch_size]
                t += 1
                # Forward Pass
                activations, pre_activations = self.forward(X_batch)
                if loss=="MSE":
                    grads=self.backward_mse(X_batch, y_batch, activations, pre_activations)
                    batch_loss = mean_squared_error(y_batch, activations[-1])
                else:
                    grads=self.backward_crossentropy(X_batch, y_batch, activations, pre_activations)
                    batch_loss = cross_entropy(y_batch, activations[-1])
    
                # Update weights
                self.update_weights(grads, learning_rate, optimizer, state, t)
                epoch_train_loss += batch_loss * X_batch.shape[0]  # Weighted by batch size
                
            # Average training loss for the epoch
            epoch_train_loss /= X_train.shape[0]
            self.train_losses.append(epoch_train_loss)
            
            # Compute validation loss
            val_activations, _ = self.forward(X_val)
            if loss == "MSE":
                val_loss = mean_squared_error(y_val, val_activations[-1])
            else:
                val_loss = cross_entropy(y_val, val_activations[-1])
            self.val_losses.append(val_loss)
            
            
            val_acc = self.evaluate(X_val, y_val)
            train_acc = self.evaluate(X_train, y_train)

            print(f"Epoch {epoch}: Validation Loss = {val_loss:.4f}, validation Accuracy = {val_acc:.2f}%, Train Accuracy = {train_acc:.2f}%")

        

    def evaluate(self, X, y):
        activations, _ = self.forward(X)
        y_pred = np.argmax(activations[-1], axis=1)
        y_true = np.argmax(y, axis=1)
        return np.mean(y_pred == y_true) * 100

    def plot_weights(self):
        fig, axes = plt.subplots(1, len(self.weights), figsize=(10, 5))
        for i, W in enumerate(self.weights):
            axes[i].imshow(W, cmap='coolwarm', aspect='auto')
            axes[i].set_title(f'Layer {i}')
        plt.show()

    def plot_losses(self):
        plt.figure(figsize=(10, 6))
        plt.plot(self.train_losses, label='Training Loss')
        plt.plot(self.val_losses, label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training and Validation Loss Over Epochs')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# # Phase 1

# %% [markdown]
# ## Prepare Dataset

# %%
def to_one_hot(labels, num_classes=10):
    one_hot = np.zeros((labels.size, num_classes))
    one_hot[np.arange(labels.size), labels] = 1
    return one_hot

train_df = pd.read_csv("mnist_train.csv",header=None)
test_df = pd.read_csv("mnist_test.csv",header=None)
# data = pd.concat([train_df, test_df])


y_temp = train_df.iloc[:, 0]
X_temp = train_df.iloc[:, 1:].values  

y_test = test_df.iloc[:, 0]
X_test = test_df.iloc[:, 1:].values  

X_train,X_val,y_train,y_val=train_test_split(X_temp, y_temp, test_size=0.1, random_state=42, stratify=y_temp)


mean = np.mean(X_train)
std = np.std(X_train)

if std == 0:
    std = 1.0

X_train = (X_train - mean) / std
X_val = (X_val - mean) / std
X_test = (X_test - mean) / std

# y_train=np.array(y_train)
# y_test=np.array(y_test)
# y_val=np.array(y_val)
y_train = to_one_hot(y_train)
y_test = to_one_hot(y_test)
y_val = to_one_hot(y_val)

print(len(X_train),len(X_val),len(X_test))
# Out:
# 54000 6000 10000

# %% [markdown]
# # Phase 2

# %% [markdown]
# ## Finding best structure

# %% [markdown]
# ### 16 16

# %%
mlp = MLP(
    layers=[16, 16],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 2: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 3: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 4: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 5: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 6: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 7: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 8: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 9: Validation Loss = 0.0896, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 10: Validation Loss = 0.0884, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 11: Validation Loss = 0.0832, validation Accuracy = 20.97%, Train Accuracy = 20.97%
# Epoch 12: Validation Loss = 0.0812, validation Accuracy = 20.95%, Train Accuracy = 20.91%
# Epoch 13: Validation Loss = 0.0807, validation Accuracy = 20.73%, Train Accuracy = 20.79%
# Epoch 14: Validation Loss = 0.0804, validation Accuracy = 25.08%, Train Accuracy = 24.89%
# Epoch 15: Validation Loss = 0.0802, validation Accuracy = 22.12%, Train Accuracy = 22.19%
# Epoch 16: Validation Loss = 0.0801, validation Accuracy = 23.68%, Train Accuracy = 23.67%
# Epoch 17: Validation Loss = 0.0800, validation Accuracy = 21.08%, Train Accuracy = 21.16%
# Epoch 18: Validation Loss = 0.0800, validation Accuracy = 21.20%, Train Accuracy = 21.34%
# Epoch 19: Validation Loss = 0.0799, validation Accuracy = 22.67%, Train Accuracy = 22.76%
# Epoch 20: Validation Loss = 0.0798, validation Accuracy = 20.85%, Train Accuracy = 20.91%
# Epoch 21: Validation Loss = 0.0797, validation Accuracy = 22.37%, Train Accuracy = 22.33%
# Epoch 22: Validation Loss = 0.0795, validation Accuracy = 25.27%, Train Accuracy = 25.04%
# Epoch 23: Validation Loss = 0.0790, validation Accuracy = 29.73%, Train Accuracy = 29.47%
# Epoch 24: Validation Loss = 0.0775, validation Accuracy = 30.60%, Train Accuracy = 30.55%
# Epoch 25: Validation Loss = 0.0744, validation Accuracy = 30.38%, Train Accuracy = 30.52%
# Epoch 26: Validation Loss = 0.0712, validation Accuracy = 33.48%, Train Accuracy = 33.72%
# Epoch 27: Validation Loss = 0.0692, validation Accuracy = 38.90%, Train Accuracy = 38.83%
# Epoch 28: Validation Loss = 0.0678, validation Accuracy = 39.00%, Train Accuracy = 38.91%
# Epoch 29: Validation Loss = 0.0668, validation Accuracy = 39.53%, Train Accuracy = 39.43%
# Epoch 30: Validation Loss = 0.0657, validation Accuracy = 39.70%, Train Accuracy = 39.22%
# Epoch 31: Validation Loss = 0.0647, validation Accuracy = 40.98%, Train Accuracy = 40.68%
# Epoch 32: Validation Loss = 0.0636, validation Accuracy = 40.53%, Train Accuracy = 40.38%
# Epoch 33: Validation Loss = 0.0624, validation Accuracy = 47.00%, Train Accuracy = 46.75%
# Epoch 34: Validation Loss = 0.0609, validation Accuracy = 50.00%, Train Accuracy = 49.97%
# Epoch 35: Validation Loss = 0.0588, validation Accuracy = 51.82%, Train Accuracy = 52.11%
# Epoch 36: Validation Loss = 0.0564, validation Accuracy = 54.87%, Train Accuracy = 55.25%
# Epoch 37: Validation Loss = 0.0542, validation Accuracy = 60.47%, Train Accuracy = 59.94%
# Epoch 38: Validation Loss = 0.0520, validation Accuracy = 56.10%, Train Accuracy = 56.16%
# Epoch 39: Validation Loss = 0.0496, validation Accuracy = 58.97%, Train Accuracy = 58.80%
# Epoch 40: Validation Loss = 0.0466, validation Accuracy = 70.72%, Train Accuracy = 71.30%
# Epoch 41: Validation Loss = 0.0431, validation Accuracy = 76.75%, Train Accuracy = 77.45%
# Epoch 42: Validation Loss = 0.0403, validation Accuracy = 77.73%, Train Accuracy = 78.67%
# Epoch 43: Validation Loss = 0.0380, validation Accuracy = 79.57%, Train Accuracy = 80.02%
# Epoch 44: Validation Loss = 0.0354, validation Accuracy = 82.42%, Train Accuracy = 82.58%
# Epoch 45: Validation Loss = 0.0325, validation Accuracy = 83.38%, Train Accuracy = 83.56%
# Epoch 46: Validation Loss = 0.0295, validation Accuracy = 85.22%, Train Accuracy = 85.84%
# Epoch 47: Validation Loss = 0.0269, validation Accuracy = 86.78%, Train Accuracy = 87.36%
# Epoch 48: Validation Loss = 0.0249, validation Accuracy = 87.23%, Train Accuracy = 88.03%
# Epoch 49: Validation Loss = 0.0232, validation Accuracy = 87.93%, Train Accuracy = 88.74%
# 88.16000000000001

# %% [markdown]
# ### 512 256

# %%
mlp = MLP(
    layers=[512, 256],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0899, validation Accuracy = 9.92%, Train Accuracy = 9.91%
# Epoch 2: Validation Loss = 0.0869, validation Accuracy = 23.55%, Train Accuracy = 23.36%
# Epoch 3: Validation Loss = 0.0666, validation Accuracy = 46.13%, Train Accuracy = 46.31%
# Epoch 4: Validation Loss = 0.0449, validation Accuracy = 69.58%, Train Accuracy = 69.54%
# Epoch 5: Validation Loss = 0.0335, validation Accuracy = 82.02%, Train Accuracy = 81.49%
# Epoch 6: Validation Loss = 0.0260, validation Accuracy = 85.98%, Train Accuracy = 85.89%
# Epoch 7: Validation Loss = 0.0215, validation Accuracy = 87.93%, Train Accuracy = 87.98%
# Epoch 8: Validation Loss = 0.0190, validation Accuracy = 89.15%, Train Accuracy = 89.06%
# Epoch 9: Validation Loss = 0.0174, validation Accuracy = 90.20%, Train Accuracy = 89.88%
# Epoch 10: Validation Loss = 0.0162, validation Accuracy = 90.80%, Train Accuracy = 90.53%
# Epoch 11: Validation Loss = 0.0152, validation Accuracy = 91.20%, Train Accuracy = 91.21%
# Epoch 12: Validation Loss = 0.0145, validation Accuracy = 91.63%, Train Accuracy = 91.72%
# Epoch 13: Validation Loss = 0.0138, validation Accuracy = 91.95%, Train Accuracy = 92.12%
# Epoch 14: Validation Loss = 0.0131, validation Accuracy = 92.48%, Train Accuracy = 92.55%
# Epoch 15: Validation Loss = 0.0125, validation Accuracy = 92.75%, Train Accuracy = 92.98%
# Epoch 16: Validation Loss = 0.0119, validation Accuracy = 93.07%, Train Accuracy = 93.34%
# Epoch 17: Validation Loss = 0.0114, validation Accuracy = 93.23%, Train Accuracy = 93.59%
# Epoch 18: Validation Loss = 0.0110, validation Accuracy = 93.45%, Train Accuracy = 93.86%
# Epoch 19: Validation Loss = 0.0106, validation Accuracy = 93.75%, Train Accuracy = 94.09%
# Epoch 20: Validation Loss = 0.0102, validation Accuracy = 94.07%, Train Accuracy = 94.44%
# Epoch 21: Validation Loss = 0.0098, validation Accuracy = 94.33%, Train Accuracy = 94.68%
# Epoch 22: Validation Loss = 0.0096, validation Accuracy = 94.48%, Train Accuracy = 94.79%
# Epoch 23: Validation Loss = 0.0093, validation Accuracy = 94.57%, Train Accuracy = 95.12%
# Epoch 24: Validation Loss = 0.0090, validation Accuracy = 94.83%, Train Accuracy = 95.34%
# Epoch 25: Validation Loss = 0.0087, validation Accuracy = 94.95%, Train Accuracy = 95.55%
# Epoch 26: Validation Loss = 0.0084, validation Accuracy = 95.17%, Train Accuracy = 95.67%
# Epoch 27: Validation Loss = 0.0083, validation Accuracy = 95.22%, Train Accuracy = 95.85%
# Epoch 28: Validation Loss = 0.0080, validation Accuracy = 95.37%, Train Accuracy = 96.00%
# Epoch 29: Validation Loss = 0.0078, validation Accuracy = 95.47%, Train Accuracy = 96.13%
# Epoch 30: Validation Loss = 0.0076, validation Accuracy = 95.68%, Train Accuracy = 96.27%
# Epoch 31: Validation Loss = 0.0074, validation Accuracy = 95.60%, Train Accuracy = 96.39%
# Epoch 32: Validation Loss = 0.0072, validation Accuracy = 95.95%, Train Accuracy = 96.53%
# Epoch 33: Validation Loss = 0.0071, validation Accuracy = 95.98%, Train Accuracy = 96.63%
# Epoch 34: Validation Loss = 0.0070, validation Accuracy = 96.05%, Train Accuracy = 96.79%
# Epoch 35: Validation Loss = 0.0067, validation Accuracy = 96.12%, Train Accuracy = 96.89%
# Epoch 36: Validation Loss = 0.0066, validation Accuracy = 96.28%, Train Accuracy = 97.02%
# Epoch 37: Validation Loss = 0.0065, validation Accuracy = 96.38%, Train Accuracy = 97.08%
# Epoch 38: Validation Loss = 0.0063, validation Accuracy = 96.33%, Train Accuracy = 97.21%
# Epoch 39: Validation Loss = 0.0063, validation Accuracy = 96.40%, Train Accuracy = 97.24%
# Epoch 40: Validation Loss = 0.0061, validation Accuracy = 96.55%, Train Accuracy = 97.36%
# Epoch 41: Validation Loss = 0.0061, validation Accuracy = 96.63%, Train Accuracy = 97.43%
# Epoch 42: Validation Loss = 0.0059, validation Accuracy = 96.80%, Train Accuracy = 97.54%
# Epoch 43: Validation Loss = 0.0058, validation Accuracy = 96.78%, Train Accuracy = 97.61%
# Epoch 44: Validation Loss = 0.0057, validation Accuracy = 96.80%, Train Accuracy = 97.68%
# Epoch 45: Validation Loss = 0.0056, validation Accuracy = 96.92%, Train Accuracy = 97.77%
# Epoch 46: Validation Loss = 0.0056, validation Accuracy = 96.97%, Train Accuracy = 97.85%
# Epoch 47: Validation Loss = 0.0055, validation Accuracy = 96.95%, Train Accuracy = 97.92%
# Epoch 48: Validation Loss = 0.0054, validation Accuracy = 97.05%, Train Accuracy = 97.95%
# Epoch 49: Validation Loss = 0.0054, validation Accuracy = 97.10%, Train Accuracy = 98.01%
# 97.15

# %% [markdown]
# ### 512 512

# %%
mlp = MLP(
    layers=[512, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=16,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0501, validation Accuracy = 63.93%, Train Accuracy = 63.88%
# Epoch 1: Validation Loss = 0.0200, validation Accuracy = 88.80%, Train Accuracy = 88.67%
# Epoch 2: Validation Loss = 0.0153, validation Accuracy = 91.30%, Train Accuracy = 91.33%
# Epoch 3: Validation Loss = 0.0124, validation Accuracy = 92.83%, Train Accuracy = 93.07%
# Epoch 4: Validation Loss = 0.0109, validation Accuracy = 93.65%, Train Accuracy = 94.09%
# Epoch 5: Validation Loss = 0.0098, validation Accuracy = 94.23%, Train Accuracy = 94.88%
# Epoch 6: Validation Loss = 0.0084, validation Accuracy = 95.10%, Train Accuracy = 95.70%
# Epoch 7: Validation Loss = 0.0077, validation Accuracy = 95.62%, Train Accuracy = 96.25%
# Epoch 8: Validation Loss = 0.0073, validation Accuracy = 95.95%, Train Accuracy = 96.61%
# Epoch 9: Validation Loss = 0.0066, validation Accuracy = 96.25%, Train Accuracy = 97.06%
# Epoch 10: Validation Loss = 0.0063, validation Accuracy = 96.42%, Train Accuracy = 97.21%
# Epoch 11: Validation Loss = 0.0057, validation Accuracy = 96.85%, Train Accuracy = 97.70%
# Epoch 12: Validation Loss = 0.0056, validation Accuracy = 96.93%, Train Accuracy = 97.81%
# Epoch 13: Validation Loss = 0.0052, validation Accuracy = 97.15%, Train Accuracy = 98.02%
# Epoch 14: Validation Loss = 0.0050, validation Accuracy = 97.23%, Train Accuracy = 98.26%
# Epoch 15: Validation Loss = 0.0050, validation Accuracy = 97.17%, Train Accuracy = 98.40%
# Epoch 16: Validation Loss = 0.0048, validation Accuracy = 97.35%, Train Accuracy = 98.48%
# Epoch 17: Validation Loss = 0.0046, validation Accuracy = 97.45%, Train Accuracy = 98.58%
# Epoch 18: Validation Loss = 0.0046, validation Accuracy = 97.38%, Train Accuracy = 98.76%
# Epoch 19: Validation Loss = 0.0043, validation Accuracy = 97.55%, Train Accuracy = 98.83%
# Epoch 20: Validation Loss = 0.0043, validation Accuracy = 97.63%, Train Accuracy = 98.91%
# Epoch 21: Validation Loss = 0.0042, validation Accuracy = 97.65%, Train Accuracy = 98.96%
# Epoch 22: Validation Loss = 0.0044, validation Accuracy = 97.65%, Train Accuracy = 98.98%
# Epoch 23: Validation Loss = 0.0041, validation Accuracy = 97.77%, Train Accuracy = 99.11%
# Epoch 24: Validation Loss = 0.0041, validation Accuracy = 97.72%, Train Accuracy = 99.15%
# Epoch 25: Validation Loss = 0.0040, validation Accuracy = 97.83%, Train Accuracy = 99.20%
# Epoch 26: Validation Loss = 0.0039, validation Accuracy = 97.82%, Train Accuracy = 99.24%
# Epoch 27: Validation Loss = 0.0041, validation Accuracy = 97.75%, Train Accuracy = 99.29%
# Epoch 28: Validation Loss = 0.0038, validation Accuracy = 97.93%, Train Accuracy = 99.32%
# Epoch 29: Validation Loss = 0.0038, validation Accuracy = 97.90%, Train Accuracy = 99.35%
# Epoch 30: Validation Loss = 0.0038, validation Accuracy = 97.98%, Train Accuracy = 99.37%
# Epoch 31: Validation Loss = 0.0038, validation Accuracy = 98.00%, Train Accuracy = 99.39%
# Epoch 32: Validation Loss = 0.0037, validation Accuracy = 97.95%, Train Accuracy = 99.40%
# Epoch 33: Validation Loss = 0.0037, validation Accuracy = 98.02%, Train Accuracy = 99.43%
# Epoch 34: Validation Loss = 0.0037, validation Accuracy = 98.08%, Train Accuracy = 99.44%
# Epoch 35: Validation Loss = 0.0037, validation Accuracy = 97.90%, Train Accuracy = 99.45%
# Epoch 36: Validation Loss = 0.0036, validation Accuracy = 98.03%, Train Accuracy = 99.49%
# Epoch 37: Validation Loss = 0.0038, validation Accuracy = 97.90%, Train Accuracy = 99.49%
# Epoch 38: Validation Loss = 0.0036, validation Accuracy = 97.98%, Train Accuracy = 99.50%
# Epoch 39: Validation Loss = 0.0036, validation Accuracy = 98.03%, Train Accuracy = 99.52%
# Epoch 40: Validation Loss = 0.0036, validation Accuracy = 97.93%, Train Accuracy = 99.53%
# Epoch 41: Validation Loss = 0.0036, validation Accuracy = 98.03%, Train Accuracy = 99.54%
# Epoch 42: Validation Loss = 0.0036, validation Accuracy = 98.00%, Train Accuracy = 99.55%
# Epoch 43: Validation Loss = 0.0036, validation Accuracy = 97.98%, Train Accuracy = 99.56%
# Epoch 44: Validation Loss = 0.0036, validation Accuracy = 98.07%, Train Accuracy = 99.57%
# Epoch 45: Validation Loss = 0.0036, validation Accuracy = 97.95%, Train Accuracy = 99.57%
# Epoch 46: Validation Loss = 0.0036, validation Accuracy = 97.98%, Train Accuracy = 99.58%
# Epoch 47: Validation Loss = 0.0035, validation Accuracy = 97.97%, Train Accuracy = 99.58%
# Epoch 48: Validation Loss = 0.0036, validation Accuracy = 97.97%, Train Accuracy = 99.59%
# Epoch 49: Validation Loss = 0.0036, validation Accuracy = 97.95%, Train Accuracy = 99.60%
# 98.09

# %% [markdown]
# ### 256 256 64

# %%
mlp = MLP(
    layers=[256, 256],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 9.75%, Train Accuracy = 9.75%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 10.45%, Train Accuracy = 10.44%
# Epoch 2: Validation Loss = 0.0896, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 3: Validation Loss = 0.0769, validation Accuracy = 31.47%, Train Accuracy = 30.91%
# Epoch 4: Validation Loss = 0.0607, validation Accuracy = 56.35%, Train Accuracy = 56.18%
# Epoch 5: Validation Loss = 0.0428, validation Accuracy = 74.27%, Train Accuracy = 73.68%
# Epoch 6: Validation Loss = 0.0346, validation Accuracy = 80.90%, Train Accuracy = 80.63%
# Epoch 7: Validation Loss = 0.0271, validation Accuracy = 85.30%, Train Accuracy = 85.16%
# Epoch 8: Validation Loss = 0.0222, validation Accuracy = 87.62%, Train Accuracy = 87.57%
# Epoch 9: Validation Loss = 0.0194, validation Accuracy = 89.00%, Train Accuracy = 88.76%
# Epoch 10: Validation Loss = 0.0177, validation Accuracy = 89.98%, Train Accuracy = 89.73%
# Epoch 11: Validation Loss = 0.0164, validation Accuracy = 90.65%, Train Accuracy = 90.38%
# Epoch 12: Validation Loss = 0.0154, validation Accuracy = 91.13%, Train Accuracy = 91.11%
# Epoch 13: Validation Loss = 0.0144, validation Accuracy = 91.48%, Train Accuracy = 91.68%
# Epoch 14: Validation Loss = 0.0137, validation Accuracy = 91.97%, Train Accuracy = 92.14%
# Epoch 15: Validation Loss = 0.0130, validation Accuracy = 92.23%, Train Accuracy = 92.62%
# Epoch 16: Validation Loss = 0.0124, validation Accuracy = 92.70%, Train Accuracy = 93.09%
# Epoch 17: Validation Loss = 0.0120, validation Accuracy = 93.12%, Train Accuracy = 93.45%
# Epoch 18: Validation Loss = 0.0114, validation Accuracy = 93.38%, Train Accuracy = 93.68%
# Epoch 19: Validation Loss = 0.0110, validation Accuracy = 93.70%, Train Accuracy = 94.14%
# Epoch 20: Validation Loss = 0.0104, validation Accuracy = 94.02%, Train Accuracy = 94.38%
# Epoch 21: Validation Loss = 0.0101, validation Accuracy = 94.17%, Train Accuracy = 94.64%
# Epoch 22: Validation Loss = 0.0097, validation Accuracy = 94.43%, Train Accuracy = 94.86%
# Epoch 23: Validation Loss = 0.0094, validation Accuracy = 94.65%, Train Accuracy = 95.11%
# Epoch 24: Validation Loss = 0.0091, validation Accuracy = 94.85%, Train Accuracy = 95.33%
# Epoch 25: Validation Loss = 0.0088, validation Accuracy = 94.97%, Train Accuracy = 95.55%
# Epoch 26: Validation Loss = 0.0086, validation Accuracy = 95.12%, Train Accuracy = 95.72%
# Epoch 27: Validation Loss = 0.0084, validation Accuracy = 95.15%, Train Accuracy = 95.86%
# Epoch 28: Validation Loss = 0.0081, validation Accuracy = 95.35%, Train Accuracy = 96.06%
# Epoch 29: Validation Loss = 0.0079, validation Accuracy = 95.48%, Train Accuracy = 96.19%
# Epoch 30: Validation Loss = 0.0077, validation Accuracy = 95.57%, Train Accuracy = 96.32%
# Epoch 31: Validation Loss = 0.0075, validation Accuracy = 95.72%, Train Accuracy = 96.51%
# Epoch 32: Validation Loss = 0.0073, validation Accuracy = 95.85%, Train Accuracy = 96.66%
# Epoch 33: Validation Loss = 0.0071, validation Accuracy = 95.85%, Train Accuracy = 96.78%
# Epoch 34: Validation Loss = 0.0070, validation Accuracy = 95.92%, Train Accuracy = 96.87%
# Epoch 35: Validation Loss = 0.0068, validation Accuracy = 96.13%, Train Accuracy = 97.00%
# Epoch 36: Validation Loss = 0.0067, validation Accuracy = 96.10%, Train Accuracy = 97.07%
# Epoch 37: Validation Loss = 0.0066, validation Accuracy = 96.22%, Train Accuracy = 97.14%
# Epoch 38: Validation Loss = 0.0065, validation Accuracy = 96.30%, Train Accuracy = 97.23%
# Epoch 39: Validation Loss = 0.0064, validation Accuracy = 96.30%, Train Accuracy = 97.33%
# Epoch 40: Validation Loss = 0.0062, validation Accuracy = 96.40%, Train Accuracy = 97.46%
# Epoch 41: Validation Loss = 0.0061, validation Accuracy = 96.45%, Train Accuracy = 97.52%
# Epoch 42: Validation Loss = 0.0060, validation Accuracy = 96.53%, Train Accuracy = 97.59%
# Epoch 43: Validation Loss = 0.0060, validation Accuracy = 96.48%, Train Accuracy = 97.68%
# Epoch 44: Validation Loss = 0.0058, validation Accuracy = 96.62%, Train Accuracy = 97.72%
# Epoch 45: Validation Loss = 0.0057, validation Accuracy = 96.78%, Train Accuracy = 97.83%
# Epoch 46: Validation Loss = 0.0057, validation Accuracy = 96.82%, Train Accuracy = 97.86%
# Epoch 47: Validation Loss = 0.0056, validation Accuracy = 96.82%, Train Accuracy = 97.93%
# Epoch 48: Validation Loss = 0.0056, validation Accuracy = 96.80%, Train Accuracy = 97.98%
# Epoch 49: Validation Loss = 0.0055, validation Accuracy = 96.85%, Train Accuracy = 98.05%
# 97.06

# %% [markdown]
# ### 256 256 128

# %%
mlp = MLP(
    layers=[256, 256],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=128,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 10.45%, Train Accuracy = 10.44%
# Epoch 2: Validation Loss = 0.0900, validation Accuracy = 9.92%, Train Accuracy = 9.91%
# Epoch 3: Validation Loss = 0.0899, validation Accuracy = 14.38%, Train Accuracy = 14.82%
# Epoch 4: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 5: Validation Loss = 0.0895, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 6: Validation Loss = 0.0867, validation Accuracy = 22.22%, Train Accuracy = 22.62%
# Epoch 7: Validation Loss = 0.0748, validation Accuracy = 34.22%, Train Accuracy = 33.92%
# Epoch 8: Validation Loss = 0.0665, validation Accuracy = 43.33%, Train Accuracy = 43.64%
# Epoch 9: Validation Loss = 0.0593, validation Accuracy = 56.05%, Train Accuracy = 56.29%
# Epoch 10: Validation Loss = 0.0488, validation Accuracy = 69.43%, Train Accuracy = 68.79%
# Epoch 11: Validation Loss = 0.0432, validation Accuracy = 72.88%, Train Accuracy = 72.49%
# Epoch 12: Validation Loss = 0.0386, validation Accuracy = 77.68%, Train Accuracy = 77.45%
# Epoch 13: Validation Loss = 0.0333, validation Accuracy = 81.80%, Train Accuracy = 81.52%
# Epoch 14: Validation Loss = 0.0293, validation Accuracy = 84.28%, Train Accuracy = 84.06%
# Epoch 15: Validation Loss = 0.0261, validation Accuracy = 86.17%, Train Accuracy = 86.06%
# Epoch 16: Validation Loss = 0.0236, validation Accuracy = 86.90%, Train Accuracy = 87.13%
# Epoch 17: Validation Loss = 0.0215, validation Accuracy = 87.83%, Train Accuracy = 87.96%
# Epoch 18: Validation Loss = 0.0200, validation Accuracy = 88.68%, Train Accuracy = 88.66%
# Epoch 19: Validation Loss = 0.0189, validation Accuracy = 89.40%, Train Accuracy = 89.14%
# Epoch 20: Validation Loss = 0.0179, validation Accuracy = 89.97%, Train Accuracy = 89.69%
# Epoch 21: Validation Loss = 0.0171, validation Accuracy = 90.38%, Train Accuracy = 90.12%
# Epoch 22: Validation Loss = 0.0164, validation Accuracy = 90.67%, Train Accuracy = 90.50%
# Epoch 23: Validation Loss = 0.0158, validation Accuracy = 91.08%, Train Accuracy = 90.87%
# Epoch 24: Validation Loss = 0.0154, validation Accuracy = 91.17%, Train Accuracy = 91.18%
# Epoch 25: Validation Loss = 0.0149, validation Accuracy = 91.27%, Train Accuracy = 91.48%
# Epoch 26: Validation Loss = 0.0145, validation Accuracy = 91.53%, Train Accuracy = 91.76%
# Epoch 27: Validation Loss = 0.0141, validation Accuracy = 91.67%, Train Accuracy = 92.00%
# Epoch 28: Validation Loss = 0.0137, validation Accuracy = 91.93%, Train Accuracy = 92.24%
# Epoch 29: Validation Loss = 0.0133, validation Accuracy = 92.30%, Train Accuracy = 92.44%
# Epoch 30: Validation Loss = 0.0130, validation Accuracy = 92.47%, Train Accuracy = 92.73%
# Epoch 31: Validation Loss = 0.0127, validation Accuracy = 92.72%, Train Accuracy = 92.92%
# Epoch 32: Validation Loss = 0.0124, validation Accuracy = 92.85%, Train Accuracy = 93.11%
# Epoch 33: Validation Loss = 0.0122, validation Accuracy = 92.90%, Train Accuracy = 93.26%
# Epoch 34: Validation Loss = 0.0119, validation Accuracy = 93.18%, Train Accuracy = 93.46%
# Epoch 35: Validation Loss = 0.0116, validation Accuracy = 93.38%, Train Accuracy = 93.62%
# Epoch 36: Validation Loss = 0.0114, validation Accuracy = 93.38%, Train Accuracy = 93.78%
# Epoch 37: Validation Loss = 0.0111, validation Accuracy = 93.58%, Train Accuracy = 93.94%
# Epoch 38: Validation Loss = 0.0109, validation Accuracy = 93.63%, Train Accuracy = 94.10%
# Epoch 39: Validation Loss = 0.0107, validation Accuracy = 93.72%, Train Accuracy = 94.25%
# Epoch 40: Validation Loss = 0.0105, validation Accuracy = 93.88%, Train Accuracy = 94.33%
# Epoch 41: Validation Loss = 0.0103, validation Accuracy = 93.90%, Train Accuracy = 94.51%
# Epoch 42: Validation Loss = 0.0101, validation Accuracy = 94.10%, Train Accuracy = 94.65%
# Epoch 43: Validation Loss = 0.0100, validation Accuracy = 94.17%, Train Accuracy = 94.72%
# Epoch 44: Validation Loss = 0.0098, validation Accuracy = 94.30%, Train Accuracy = 94.84%
# Epoch 45: Validation Loss = 0.0096, validation Accuracy = 94.45%, Train Accuracy = 94.98%
# Epoch 46: Validation Loss = 0.0094, validation Accuracy = 94.42%, Train Accuracy = 95.11%
# Epoch 47: Validation Loss = 0.0093, validation Accuracy = 94.60%, Train Accuracy = 95.22%
# Epoch 48: Validation Loss = 0.0091, validation Accuracy = 94.72%, Train Accuracy = 95.34%
# Epoch 49: Validation Loss = 0.0090, validation Accuracy = 94.80%, Train Accuracy = 95.47%
# 95.27

# %% [markdown]
# ### 1024 512 64

# %%
mlp = MLP(
    layers=[1024, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0899, validation Accuracy = 10.22%, Train Accuracy = 10.22%
# Epoch 1: Validation Loss = 0.0813, validation Accuracy = 21.02%, Train Accuracy = 21.03%
# Epoch 2: Validation Loss = 0.0508, validation Accuracy = 65.43%, Train Accuracy = 65.61%
# Epoch 3: Validation Loss = 0.0364, validation Accuracy = 81.43%, Train Accuracy = 81.39%
# Epoch 4: Validation Loss = 0.0269, validation Accuracy = 85.93%, Train Accuracy = 85.91%
# Epoch 5: Validation Loss = 0.0223, validation Accuracy = 88.02%, Train Accuracy = 88.08%
# Epoch 6: Validation Loss = 0.0196, validation Accuracy = 89.33%, Train Accuracy = 89.37%
# Epoch 7: Validation Loss = 0.0180, validation Accuracy = 90.13%, Train Accuracy = 90.10%
# Epoch 8: Validation Loss = 0.0165, validation Accuracy = 90.90%, Train Accuracy = 90.74%
# Epoch 9: Validation Loss = 0.0155, validation Accuracy = 91.13%, Train Accuracy = 91.36%
# Epoch 10: Validation Loss = 0.0147, validation Accuracy = 91.65%, Train Accuracy = 91.71%
# Epoch 11: Validation Loss = 0.0141, validation Accuracy = 91.95%, Train Accuracy = 92.09%
# Epoch 12: Validation Loss = 0.0135, validation Accuracy = 92.18%, Train Accuracy = 92.43%
# Epoch 13: Validation Loss = 0.0130, validation Accuracy = 92.62%, Train Accuracy = 92.72%
# Epoch 14: Validation Loss = 0.0124, validation Accuracy = 92.80%, Train Accuracy = 93.04%
# Epoch 15: Validation Loss = 0.0122, validation Accuracy = 93.03%, Train Accuracy = 93.17%
# Epoch 16: Validation Loss = 0.0117, validation Accuracy = 93.28%, Train Accuracy = 93.47%
# Epoch 17: Validation Loss = 0.0114, validation Accuracy = 93.37%, Train Accuracy = 93.62%
# Epoch 18: Validation Loss = 0.0113, validation Accuracy = 93.60%, Train Accuracy = 93.79%
# Epoch 19: Validation Loss = 0.0108, validation Accuracy = 93.70%, Train Accuracy = 94.04%
# Epoch 20: Validation Loss = 0.0104, validation Accuracy = 93.98%, Train Accuracy = 94.34%
# Epoch 21: Validation Loss = 0.0101, validation Accuracy = 94.25%, Train Accuracy = 94.52%
# Epoch 22: Validation Loss = 0.0100, validation Accuracy = 94.37%, Train Accuracy = 94.69%
# Epoch 23: Validation Loss = 0.0097, validation Accuracy = 94.47%, Train Accuracy = 94.87%
# Epoch 24: Validation Loss = 0.0094, validation Accuracy = 94.62%, Train Accuracy = 95.02%
# Epoch 25: Validation Loss = 0.0092, validation Accuracy = 94.68%, Train Accuracy = 95.26%
# Epoch 26: Validation Loss = 0.0090, validation Accuracy = 94.90%, Train Accuracy = 95.41%
# Epoch 27: Validation Loss = 0.0088, validation Accuracy = 95.08%, Train Accuracy = 95.52%
# Epoch 28: Validation Loss = 0.0085, validation Accuracy = 95.12%, Train Accuracy = 95.71%
# Epoch 29: Validation Loss = 0.0083, validation Accuracy = 95.20%, Train Accuracy = 95.82%
# Epoch 30: Validation Loss = 0.0083, validation Accuracy = 95.18%, Train Accuracy = 95.99%
# Epoch 31: Validation Loss = 0.0080, validation Accuracy = 95.50%, Train Accuracy = 96.05%
# Epoch 32: Validation Loss = 0.0079, validation Accuracy = 95.63%, Train Accuracy = 96.20%
# Epoch 33: Validation Loss = 0.0077, validation Accuracy = 95.70%, Train Accuracy = 96.32%
# Epoch 34: Validation Loss = 0.0075, validation Accuracy = 95.83%, Train Accuracy = 96.40%
# Epoch 35: Validation Loss = 0.0074, validation Accuracy = 95.82%, Train Accuracy = 96.52%
# Epoch 36: Validation Loss = 0.0073, validation Accuracy = 95.78%, Train Accuracy = 96.60%
# Epoch 37: Validation Loss = 0.0071, validation Accuracy = 95.98%, Train Accuracy = 96.73%
# Epoch 38: Validation Loss = 0.0071, validation Accuracy = 95.97%, Train Accuracy = 96.71%
# Epoch 39: Validation Loss = 0.0068, validation Accuracy = 96.10%, Train Accuracy = 96.90%
# Epoch 40: Validation Loss = 0.0067, validation Accuracy = 96.17%, Train Accuracy = 97.02%
# Epoch 41: Validation Loss = 0.0066, validation Accuracy = 96.25%, Train Accuracy = 97.06%
# Epoch 42: Validation Loss = 0.0066, validation Accuracy = 96.18%, Train Accuracy = 97.13%
# Epoch 43: Validation Loss = 0.0064, validation Accuracy = 96.33%, Train Accuracy = 97.24%
# Epoch 44: Validation Loss = 0.0063, validation Accuracy = 96.38%, Train Accuracy = 97.29%
# Epoch 45: Validation Loss = 0.0062, validation Accuracy = 96.52%, Train Accuracy = 97.31%
# Epoch 46: Validation Loss = 0.0061, validation Accuracy = 96.45%, Train Accuracy = 97.43%
# Epoch 47: Validation Loss = 0.0061, validation Accuracy = 96.45%, Train Accuracy = 97.51%
# Epoch 48: Validation Loss = 0.0060, validation Accuracy = 96.65%, Train Accuracy = 97.56%
# Epoch 49: Validation Loss = 0.0058, validation Accuracy = 96.62%, Train Accuracy = 97.67%
# 96.93

# %% [markdown]
# ### 1024 1024

# %%
mlp = MLP(
    layers=[1024, 1024],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0902, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 1: Validation Loss = 0.0714, validation Accuracy = 45.82%, Train Accuracy = 45.62%
# Epoch 2: Validation Loss = 0.0433, validation Accuracy = 73.53%, Train Accuracy = 73.78%
# Epoch 3: Validation Loss = 0.0297, validation Accuracy = 84.73%, Train Accuracy = 84.99%
# Epoch 4: Validation Loss = 0.0250, validation Accuracy = 87.38%, Train Accuracy = 87.35%
# Epoch 5: Validation Loss = 0.0208, validation Accuracy = 89.22%, Train Accuracy = 89.05%
# Epoch 6: Validation Loss = 0.0189, validation Accuracy = 90.12%, Train Accuracy = 89.94%
# Epoch 7: Validation Loss = 0.0176, validation Accuracy = 90.58%, Train Accuracy = 90.44%
# Epoch 8: Validation Loss = 0.0162, validation Accuracy = 91.18%, Train Accuracy = 91.24%
# Epoch 9: Validation Loss = 0.0153, validation Accuracy = 91.78%, Train Accuracy = 91.77%
# Epoch 10: Validation Loss = 0.0145, validation Accuracy = 92.02%, Train Accuracy = 92.21%
# Epoch 11: Validation Loss = 0.0138, validation Accuracy = 92.20%, Train Accuracy = 92.46%
# Epoch 12: Validation Loss = 0.0133, validation Accuracy = 92.58%, Train Accuracy = 92.78%
# Epoch 13: Validation Loss = 0.0128, validation Accuracy = 92.90%, Train Accuracy = 93.04%
# Epoch 14: Validation Loss = 0.0123, validation Accuracy = 93.08%, Train Accuracy = 93.40%
# Epoch 15: Validation Loss = 0.0118, validation Accuracy = 93.30%, Train Accuracy = 93.67%
# Epoch 16: Validation Loss = 0.0115, validation Accuracy = 93.67%, Train Accuracy = 93.92%
# Epoch 17: Validation Loss = 0.0112, validation Accuracy = 93.85%, Train Accuracy = 94.07%
# Epoch 18: Validation Loss = 0.0108, validation Accuracy = 94.02%, Train Accuracy = 94.39%
# Epoch 19: Validation Loss = 0.0105, validation Accuracy = 94.02%, Train Accuracy = 94.51%
# Epoch 20: Validation Loss = 0.0102, validation Accuracy = 94.38%, Train Accuracy = 94.77%
# Epoch 21: Validation Loss = 0.0100, validation Accuracy = 94.50%, Train Accuracy = 94.91%
# Epoch 22: Validation Loss = 0.0096, validation Accuracy = 94.77%, Train Accuracy = 95.16%
# Epoch 23: Validation Loss = 0.0093, validation Accuracy = 94.83%, Train Accuracy = 95.29%
# Epoch 24: Validation Loss = 0.0091, validation Accuracy = 95.03%, Train Accuracy = 95.44%
# Epoch 25: Validation Loss = 0.0088, validation Accuracy = 95.22%, Train Accuracy = 95.65%
# Epoch 26: Validation Loss = 0.0087, validation Accuracy = 95.20%, Train Accuracy = 95.71%
# Epoch 27: Validation Loss = 0.0084, validation Accuracy = 95.35%, Train Accuracy = 95.92%
# Epoch 28: Validation Loss = 0.0082, validation Accuracy = 95.57%, Train Accuracy = 96.08%
# Epoch 29: Validation Loss = 0.0082, validation Accuracy = 95.48%, Train Accuracy = 96.02%
# Epoch 30: Validation Loss = 0.0079, validation Accuracy = 95.78%, Train Accuracy = 96.26%
# Epoch 31: Validation Loss = 0.0077, validation Accuracy = 95.65%, Train Accuracy = 96.42%
# Epoch 32: Validation Loss = 0.0075, validation Accuracy = 95.83%, Train Accuracy = 96.57%
# Epoch 33: Validation Loss = 0.0074, validation Accuracy = 95.90%, Train Accuracy = 96.67%
# Epoch 34: Validation Loss = 0.0072, validation Accuracy = 95.98%, Train Accuracy = 96.78%
# Epoch 35: Validation Loss = 0.0073, validation Accuracy = 95.88%, Train Accuracy = 96.76%
# Epoch 36: Validation Loss = 0.0071, validation Accuracy = 95.97%, Train Accuracy = 96.83%
# Epoch 37: Validation Loss = 0.0068, validation Accuracy = 96.25%, Train Accuracy = 97.06%
# Epoch 38: Validation Loss = 0.0067, validation Accuracy = 96.28%, Train Accuracy = 97.15%
# Epoch 39: Validation Loss = 0.0066, validation Accuracy = 96.33%, Train Accuracy = 97.22%
# Epoch 40: Validation Loss = 0.0064, validation Accuracy = 96.38%, Train Accuracy = 97.31%
# Epoch 41: Validation Loss = 0.0064, validation Accuracy = 96.62%, Train Accuracy = 97.39%
# Epoch 42: Validation Loss = 0.0063, validation Accuracy = 96.55%, Train Accuracy = 97.40%
# Epoch 43: Validation Loss = 0.0062, validation Accuracy = 96.58%, Train Accuracy = 97.51%
# Epoch 44: Validation Loss = 0.0061, validation Accuracy = 96.60%, Train Accuracy = 97.56%
# Epoch 45: Validation Loss = 0.0060, validation Accuracy = 96.85%, Train Accuracy = 97.61%
# Epoch 46: Validation Loss = 0.0059, validation Accuracy = 96.80%, Train Accuracy = 97.71%
# Epoch 47: Validation Loss = 0.0060, validation Accuracy = 96.60%, Train Accuracy = 97.74%
# Epoch 48: Validation Loss = 0.0057, validation Accuracy = 96.85%, Train Accuracy = 97.85%
# Epoch 49: Validation Loss = 0.0056, validation Accuracy = 97.00%, Train Accuracy = 97.94%
# 97.03

# %% [markdown]
# ### 128 128

# %%
mlp = MLP(
    layers=[128, 128],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 2: Validation Loss = 0.0900, validation Accuracy = 9.87%, Train Accuracy = 9.86%
# Epoch 3: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 4: Validation Loss = 0.0891, validation Accuracy = 25.08%, Train Accuracy = 25.57%
# Epoch 5: Validation Loss = 0.0760, validation Accuracy = 32.23%, Train Accuracy = 32.58%
# Epoch 6: Validation Loss = 0.0639, validation Accuracy = 49.43%, Train Accuracy = 49.56%
# Epoch 7: Validation Loss = 0.0488, validation Accuracy = 70.10%, Train Accuracy = 69.88%
# Epoch 8: Validation Loss = 0.0386, validation Accuracy = 77.52%, Train Accuracy = 77.41%
# Epoch 9: Validation Loss = 0.0297, validation Accuracy = 83.75%, Train Accuracy = 83.51%
# Epoch 10: Validation Loss = 0.0240, validation Accuracy = 86.43%, Train Accuracy = 86.74%
# Epoch 11: Validation Loss = 0.0204, validation Accuracy = 88.18%, Train Accuracy = 88.31%
# Epoch 12: Validation Loss = 0.0183, validation Accuracy = 89.32%, Train Accuracy = 89.24%
# Epoch 13: Validation Loss = 0.0168, validation Accuracy = 90.23%, Train Accuracy = 90.11%
# Epoch 14: Validation Loss = 0.0156, validation Accuracy = 90.87%, Train Accuracy = 90.85%
# Epoch 15: Validation Loss = 0.0147, validation Accuracy = 91.37%, Train Accuracy = 91.45%
# Epoch 16: Validation Loss = 0.0139, validation Accuracy = 91.82%, Train Accuracy = 91.98%
# Epoch 17: Validation Loss = 0.0132, validation Accuracy = 92.25%, Train Accuracy = 92.48%
# Epoch 18: Validation Loss = 0.0126, validation Accuracy = 92.58%, Train Accuracy = 92.94%
# Epoch 19: Validation Loss = 0.0120, validation Accuracy = 92.87%, Train Accuracy = 93.32%
# Epoch 20: Validation Loss = 0.0115, validation Accuracy = 93.27%, Train Accuracy = 93.71%
# Epoch 21: Validation Loss = 0.0111, validation Accuracy = 93.72%, Train Accuracy = 93.97%
# Epoch 22: Validation Loss = 0.0106, validation Accuracy = 93.88%, Train Accuracy = 94.32%
# Epoch 23: Validation Loss = 0.0102, validation Accuracy = 94.17%, Train Accuracy = 94.58%
# Epoch 24: Validation Loss = 0.0099, validation Accuracy = 94.28%, Train Accuracy = 94.84%
# Epoch 25: Validation Loss = 0.0096, validation Accuracy = 94.57%, Train Accuracy = 95.13%
# Epoch 26: Validation Loss = 0.0093, validation Accuracy = 94.72%, Train Accuracy = 95.36%
# Epoch 27: Validation Loss = 0.0090, validation Accuracy = 94.85%, Train Accuracy = 95.55%
# Epoch 28: Validation Loss = 0.0087, validation Accuracy = 94.95%, Train Accuracy = 95.73%
# Epoch 29: Validation Loss = 0.0085, validation Accuracy = 95.12%, Train Accuracy = 95.98%
# Epoch 30: Validation Loss = 0.0083, validation Accuracy = 95.15%, Train Accuracy = 96.09%
# Epoch 31: Validation Loss = 0.0081, validation Accuracy = 95.25%, Train Accuracy = 96.21%
# Epoch 32: Validation Loss = 0.0079, validation Accuracy = 95.35%, Train Accuracy = 96.37%
# Epoch 33: Validation Loss = 0.0077, validation Accuracy = 95.52%, Train Accuracy = 96.54%
# Epoch 34: Validation Loss = 0.0075, validation Accuracy = 95.65%, Train Accuracy = 96.63%
# Epoch 35: Validation Loss = 0.0074, validation Accuracy = 95.70%, Train Accuracy = 96.76%
# Epoch 36: Validation Loss = 0.0072, validation Accuracy = 95.80%, Train Accuracy = 96.89%
# Epoch 37: Validation Loss = 0.0071, validation Accuracy = 95.93%, Train Accuracy = 97.02%
# Epoch 38: Validation Loss = 0.0069, validation Accuracy = 95.87%, Train Accuracy = 97.09%
# Epoch 39: Validation Loss = 0.0068, validation Accuracy = 96.03%, Train Accuracy = 97.17%
# Epoch 40: Validation Loss = 0.0067, validation Accuracy = 96.05%, Train Accuracy = 97.30%
# Epoch 41: Validation Loss = 0.0066, validation Accuracy = 96.17%, Train Accuracy = 97.36%
# Epoch 42: Validation Loss = 0.0064, validation Accuracy = 96.25%, Train Accuracy = 97.47%
# Epoch 43: Validation Loss = 0.0064, validation Accuracy = 96.32%, Train Accuracy = 97.54%
# Epoch 44: Validation Loss = 0.0062, validation Accuracy = 96.28%, Train Accuracy = 97.59%
# Epoch 45: Validation Loss = 0.0062, validation Accuracy = 96.40%, Train Accuracy = 97.67%
# Epoch 46: Validation Loss = 0.0062, validation Accuracy = 96.47%, Train Accuracy = 97.76%
# Epoch 47: Validation Loss = 0.0060, validation Accuracy = 96.53%, Train Accuracy = 97.81%
# Epoch 48: Validation Loss = 0.0059, validation Accuracy = 96.55%, Train Accuracy = 97.89%
# Epoch 49: Validation Loss = 0.0059, validation Accuracy = 96.50%, Train Accuracy = 97.94%
# 96.91

# %% [markdown]
# ### 64 64

# %%
mlp = MLP(
    layers=[64, 64],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))

# %% [markdown]
# ### 32 32

# %%
mlp = MLP(
    layers=[32, 32],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=64,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 2: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 3: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 4: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 5: Validation Loss = 0.0900, validation Accuracy = 10.22%, Train Accuracy = 10.22%
# Epoch 6: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 7: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 8: Validation Loss = 0.0894, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 9: Validation Loss = 0.0831, validation Accuracy = 21.00%, Train Accuracy = 20.99%
# Epoch 10: Validation Loss = 0.0807, validation Accuracy = 22.15%, Train Accuracy = 22.19%
# Epoch 11: Validation Loss = 0.0801, validation Accuracy = 23.17%, Train Accuracy = 23.17%
# Epoch 12: Validation Loss = 0.0788, validation Accuracy = 23.97%, Train Accuracy = 23.76%
# Epoch 13: Validation Loss = 0.0743, validation Accuracy = 30.77%, Train Accuracy = 30.75%
# Epoch 14: Validation Loss = 0.0724, validation Accuracy = 30.27%, Train Accuracy = 30.36%
# Epoch 15: Validation Loss = 0.0715, validation Accuracy = 37.87%, Train Accuracy = 37.67%
# Epoch 16: Validation Loss = 0.0704, validation Accuracy = 42.10%, Train Accuracy = 42.18%
# Epoch 17: Validation Loss = 0.0678, validation Accuracy = 39.48%, Train Accuracy = 39.71%
# Epoch 18: Validation Loss = 0.0646, validation Accuracy = 42.17%, Train Accuracy = 42.03%
# Epoch 19: Validation Loss = 0.0624, validation Accuracy = 49.52%, Train Accuracy = 49.15%
# Epoch 20: Validation Loss = 0.0587, validation Accuracy = 61.07%, Train Accuracy = 61.00%
# Epoch 21: Validation Loss = 0.0532, validation Accuracy = 66.55%, Train Accuracy = 66.60%
# Epoch 22: Validation Loss = 0.0479, validation Accuracy = 70.48%, Train Accuracy = 70.97%
# Epoch 23: Validation Loss = 0.0420, validation Accuracy = 75.85%, Train Accuracy = 76.48%
# Epoch 24: Validation Loss = 0.0366, validation Accuracy = 82.67%, Train Accuracy = 82.68%
# Epoch 25: Validation Loss = 0.0326, validation Accuracy = 85.85%, Train Accuracy = 85.94%
# Epoch 26: Validation Loss = 0.0289, validation Accuracy = 86.83%, Train Accuracy = 86.86%
# Epoch 27: Validation Loss = 0.0253, validation Accuracy = 88.05%, Train Accuracy = 88.25%
# Epoch 28: Validation Loss = 0.0223, validation Accuracy = 88.87%, Train Accuracy = 89.32%
# Epoch 29: Validation Loss = 0.0199, validation Accuracy = 90.03%, Train Accuracy = 90.33%
# Epoch 30: Validation Loss = 0.0180, validation Accuracy = 90.55%, Train Accuracy = 90.93%
# Epoch 31: Validation Loss = 0.0167, validation Accuracy = 90.98%, Train Accuracy = 91.37%
# Epoch 32: Validation Loss = 0.0158, validation Accuracy = 91.28%, Train Accuracy = 91.79%
# Epoch 33: Validation Loss = 0.0150, validation Accuracy = 91.48%, Train Accuracy = 92.17%
# Epoch 34: Validation Loss = 0.0142, validation Accuracy = 91.92%, Train Accuracy = 92.56%
# Epoch 35: Validation Loss = 0.0138, validation Accuracy = 91.98%, Train Accuracy = 92.78%
# Epoch 36: Validation Loss = 0.0134, validation Accuracy = 92.32%, Train Accuracy = 93.16%
# Epoch 37: Validation Loss = 0.0129, validation Accuracy = 92.48%, Train Accuracy = 93.40%
# Epoch 38: Validation Loss = 0.0126, validation Accuracy = 92.62%, Train Accuracy = 93.57%
# Epoch 39: Validation Loss = 0.0122, validation Accuracy = 92.77%, Train Accuracy = 93.92%
# Epoch 40: Validation Loss = 0.0119, validation Accuracy = 93.02%, Train Accuracy = 94.07%
# Epoch 41: Validation Loss = 0.0117, validation Accuracy = 93.23%, Train Accuracy = 94.25%
# Epoch 42: Validation Loss = 0.0114, validation Accuracy = 93.17%, Train Accuracy = 94.40%
# Epoch 43: Validation Loss = 0.0112, validation Accuracy = 93.27%, Train Accuracy = 94.62%
# Epoch 44: Validation Loss = 0.0109, validation Accuracy = 93.48%, Train Accuracy = 94.80%
# Epoch 45: Validation Loss = 0.0108, validation Accuracy = 93.47%, Train Accuracy = 94.95%
# Epoch 46: Validation Loss = 0.0106, validation Accuracy = 93.48%, Train Accuracy = 95.02%
# Epoch 47: Validation Loss = 0.0105, validation Accuracy = 93.60%, Train Accuracy = 95.16%
# Epoch 48: Validation Loss = 0.0103, validation Accuracy = 93.62%, Train Accuracy = 95.27%
# Epoch 49: Validation Loss = 0.0101, validation Accuracy = 93.87%, Train Accuracy = 95.39%
# 93.81

# %% [markdown]
# ## 3 Layer mlp with lr = 1 , 0.1 , 0.01 0.001

# %% [markdown]
# ### lr 1

# %%
mlp = MLP(
    layers=[512, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=16,
    learning_rate=1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 1: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 2: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 3: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 4: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 5: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 6: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 7: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 8: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 9: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 10: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 11: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 12: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 13: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 14: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 15: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 16: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 17: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 18: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 19: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 20: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 21: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 22: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 23: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 24: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 25: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 26: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 27: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 28: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 29: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 30: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 31: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 32: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 33: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# Epoch 34: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 35: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 36: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 37: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 38: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 39: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 40: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 41: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 42: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 43: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 44: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 45: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 46: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 47: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 48: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 49: Validation Loss = 0.1000, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# 8.92

# %% [markdown]
# ### lr 0.1

# %%
mlp = MLP(
    layers=[512, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=16,
    learning_rate=0.1,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0506, validation Accuracy = 66.87%, Train Accuracy = 66.49%
# Epoch 1: Validation Loss = 0.0203, validation Accuracy = 88.68%, Train Accuracy = 88.55%
# Epoch 2: Validation Loss = 0.0152, validation Accuracy = 91.30%, Train Accuracy = 91.36%
# Epoch 3: Validation Loss = 0.0125, validation Accuracy = 92.68%, Train Accuracy = 93.08%
# Epoch 4: Validation Loss = 0.0109, validation Accuracy = 93.70%, Train Accuracy = 94.10%
# Epoch 5: Validation Loss = 0.0097, validation Accuracy = 94.40%, Train Accuracy = 94.98%
# Epoch 6: Validation Loss = 0.0085, validation Accuracy = 95.22%, Train Accuracy = 95.67%
# Epoch 7: Validation Loss = 0.0077, validation Accuracy = 95.55%, Train Accuracy = 96.19%
# Epoch 8: Validation Loss = 0.0071, validation Accuracy = 95.82%, Train Accuracy = 96.60%
# Epoch 9: Validation Loss = 0.0066, validation Accuracy = 96.20%, Train Accuracy = 97.00%
# Epoch 10: Validation Loss = 0.0061, validation Accuracy = 96.53%, Train Accuracy = 97.34%
# Epoch 11: Validation Loss = 0.0061, validation Accuracy = 96.63%, Train Accuracy = 97.50%
# Epoch 12: Validation Loss = 0.0057, validation Accuracy = 96.83%, Train Accuracy = 97.80%
# Epoch 13: Validation Loss = 0.0053, validation Accuracy = 96.95%, Train Accuracy = 98.05%
# Epoch 14: Validation Loss = 0.0053, validation Accuracy = 97.05%, Train Accuracy = 98.13%
# Epoch 15: Validation Loss = 0.0049, validation Accuracy = 97.15%, Train Accuracy = 98.36%
# Epoch 16: Validation Loss = 0.0047, validation Accuracy = 97.35%, Train Accuracy = 98.51%
# Epoch 17: Validation Loss = 0.0046, validation Accuracy = 97.37%, Train Accuracy = 98.64%
# Epoch 18: Validation Loss = 0.0045, validation Accuracy = 97.52%, Train Accuracy = 98.74%
# Epoch 19: Validation Loss = 0.0043, validation Accuracy = 97.60%, Train Accuracy = 98.85%
# Epoch 20: Validation Loss = 0.0043, validation Accuracy = 97.57%, Train Accuracy = 98.89%
# Epoch 21: Validation Loss = 0.0042, validation Accuracy = 97.65%, Train Accuracy = 98.97%
# Epoch 22: Validation Loss = 0.0044, validation Accuracy = 97.57%, Train Accuracy = 98.97%
# Epoch 23: Validation Loss = 0.0042, validation Accuracy = 97.75%, Train Accuracy = 99.12%
# Epoch 24: Validation Loss = 0.0040, validation Accuracy = 97.77%, Train Accuracy = 99.15%
# Epoch 25: Validation Loss = 0.0040, validation Accuracy = 97.73%, Train Accuracy = 99.16%
# Epoch 26: Validation Loss = 0.0040, validation Accuracy = 97.92%, Train Accuracy = 99.24%
# Epoch 27: Validation Loss = 0.0038, validation Accuracy = 97.90%, Train Accuracy = 99.27%
# Epoch 28: Validation Loss = 0.0038, validation Accuracy = 97.87%, Train Accuracy = 99.30%
# Epoch 29: Validation Loss = 0.0038, validation Accuracy = 97.95%, Train Accuracy = 99.36%
# Epoch 30: Validation Loss = 0.0039, validation Accuracy = 97.83%, Train Accuracy = 99.37%
# Epoch 31: Validation Loss = 0.0038, validation Accuracy = 97.98%, Train Accuracy = 99.41%
# Epoch 32: Validation Loss = 0.0037, validation Accuracy = 97.90%, Train Accuracy = 99.45%
# Epoch 33: Validation Loss = 0.0037, validation Accuracy = 98.07%, Train Accuracy = 99.45%
# Epoch 34: Validation Loss = 0.0037, validation Accuracy = 97.97%, Train Accuracy = 99.48%
# Epoch 35: Validation Loss = 0.0037, validation Accuracy = 98.05%, Train Accuracy = 99.48%
# Epoch 36: Validation Loss = 0.0036, validation Accuracy = 98.05%, Train Accuracy = 99.51%
# Epoch 37: Validation Loss = 0.0036, validation Accuracy = 98.08%, Train Accuracy = 99.53%
# Epoch 38: Validation Loss = 0.0037, validation Accuracy = 98.05%, Train Accuracy = 99.54%
# Epoch 39: Validation Loss = 0.0035, validation Accuracy = 98.17%, Train Accuracy = 99.56%
# Epoch 40: Validation Loss = 0.0036, validation Accuracy = 98.10%, Train Accuracy = 99.56%
# Epoch 41: Validation Loss = 0.0035, validation Accuracy = 98.08%, Train Accuracy = 99.58%
# Epoch 42: Validation Loss = 0.0035, validation Accuracy = 98.08%, Train Accuracy = 99.59%
# Epoch 43: Validation Loss = 0.0036, validation Accuracy = 98.00%, Train Accuracy = 99.60%
# Epoch 44: Validation Loss = 0.0035, validation Accuracy = 98.08%, Train Accuracy = 99.61%
# Epoch 45: Validation Loss = 0.0035, validation Accuracy = 98.02%, Train Accuracy = 99.62%
# Epoch 46: Validation Loss = 0.0035, validation Accuracy = 98.17%, Train Accuracy = 99.62%
# Epoch 47: Validation Loss = 0.0035, validation Accuracy = 98.10%, Train Accuracy = 99.63%
# Epoch 48: Validation Loss = 0.0035, validation Accuracy = 98.05%, Train Accuracy = 99.64%
# Epoch 49: Validation Loss = 0.0035, validation Accuracy = 98.20%, Train Accuracy = 99.64%
# 98.07000000000001

# %% [markdown]
# ### lr 0.01

# %%
mlp = MLP(
    layers=[512, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=16,
    learning_rate=0.01,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 9.93%, Train Accuracy = 9.93%
# Epoch 1: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 2: Validation Loss = 0.0898, validation Accuracy = 11.88%, Train Accuracy = 11.98%
# Epoch 3: Validation Loss = 0.0896, validation Accuracy = 21.58%, Train Accuracy = 21.79%
# Epoch 4: Validation Loss = 0.0888, validation Accuracy = 22.28%, Train Accuracy = 22.59%
# Epoch 5: Validation Loss = 0.0812, validation Accuracy = 22.03%, Train Accuracy = 22.12%
# Epoch 6: Validation Loss = 0.0728, validation Accuracy = 43.42%, Train Accuracy = 43.34%
# Epoch 7: Validation Loss = 0.0643, validation Accuracy = 50.88%, Train Accuracy = 51.40%
# Epoch 8: Validation Loss = 0.0517, validation Accuracy = 68.13%, Train Accuracy = 68.26%
# Epoch 9: Validation Loss = 0.0451, validation Accuracy = 70.27%, Train Accuracy = 70.54%
# Epoch 10: Validation Loss = 0.0405, validation Accuracy = 76.00%, Train Accuracy = 76.01%
# Epoch 11: Validation Loss = 0.0357, validation Accuracy = 80.27%, Train Accuracy = 80.13%
# Epoch 12: Validation Loss = 0.0316, validation Accuracy = 83.80%, Train Accuracy = 83.47%
# Epoch 13: Validation Loss = 0.0283, validation Accuracy = 85.08%, Train Accuracy = 85.30%
# Epoch 14: Validation Loss = 0.0257, validation Accuracy = 86.42%, Train Accuracy = 86.50%
# Epoch 15: Validation Loss = 0.0238, validation Accuracy = 87.22%, Train Accuracy = 87.40%
# Epoch 16: Validation Loss = 0.0222, validation Accuracy = 87.87%, Train Accuracy = 87.97%
# Epoch 17: Validation Loss = 0.0210, validation Accuracy = 88.47%, Train Accuracy = 88.56%
# Epoch 18: Validation Loss = 0.0200, validation Accuracy = 88.88%, Train Accuracy = 89.00%
# Epoch 19: Validation Loss = 0.0191, validation Accuracy = 89.45%, Train Accuracy = 89.44%
# Epoch 20: Validation Loss = 0.0184, validation Accuracy = 89.88%, Train Accuracy = 89.69%
# Epoch 21: Validation Loss = 0.0178, validation Accuracy = 90.22%, Train Accuracy = 89.99%
# Epoch 22: Validation Loss = 0.0173, validation Accuracy = 90.48%, Train Accuracy = 90.26%
# Epoch 23: Validation Loss = 0.0167, validation Accuracy = 90.85%, Train Accuracy = 90.59%
# Epoch 24: Validation Loss = 0.0163, validation Accuracy = 90.97%, Train Accuracy = 90.76%
# Epoch 25: Validation Loss = 0.0159, validation Accuracy = 91.23%, Train Accuracy = 91.04%
# Epoch 26: Validation Loss = 0.0155, validation Accuracy = 91.30%, Train Accuracy = 91.27%
# Epoch 27: Validation Loss = 0.0151, validation Accuracy = 91.58%, Train Accuracy = 91.44%
# Epoch 28: Validation Loss = 0.0148, validation Accuracy = 91.58%, Train Accuracy = 91.64%
# Epoch 29: Validation Loss = 0.0145, validation Accuracy = 91.80%, Train Accuracy = 91.86%
# Epoch 30: Validation Loss = 0.0142, validation Accuracy = 92.07%, Train Accuracy = 91.98%
# Epoch 31: Validation Loss = 0.0139, validation Accuracy = 92.15%, Train Accuracy = 92.17%
# Epoch 32: Validation Loss = 0.0136, validation Accuracy = 92.30%, Train Accuracy = 92.39%
# Epoch 33: Validation Loss = 0.0133, validation Accuracy = 92.52%, Train Accuracy = 92.54%
# Epoch 34: Validation Loss = 0.0131, validation Accuracy = 92.62%, Train Accuracy = 92.69%
# Epoch 35: Validation Loss = 0.0129, validation Accuracy = 92.73%, Train Accuracy = 92.86%
# Epoch 36: Validation Loss = 0.0126, validation Accuracy = 92.73%, Train Accuracy = 92.98%
# Epoch 37: Validation Loss = 0.0124, validation Accuracy = 92.93%, Train Accuracy = 93.12%
# Epoch 38: Validation Loss = 0.0121, validation Accuracy = 92.93%, Train Accuracy = 93.34%
# Epoch 39: Validation Loss = 0.0119, validation Accuracy = 93.08%, Train Accuracy = 93.42%
# Epoch 40: Validation Loss = 0.0117, validation Accuracy = 93.17%, Train Accuracy = 93.59%
# Epoch 41: Validation Loss = 0.0115, validation Accuracy = 93.40%, Train Accuracy = 93.74%
# Epoch 42: Validation Loss = 0.0113, validation Accuracy = 93.42%, Train Accuracy = 93.80%
# Epoch 43: Validation Loss = 0.0111, validation Accuracy = 93.65%, Train Accuracy = 93.88%
# Epoch 44: Validation Loss = 0.0110, validation Accuracy = 93.72%, Train Accuracy = 94.04%
# Epoch 45: Validation Loss = 0.0107, validation Accuracy = 93.83%, Train Accuracy = 94.09%
# Epoch 46: Validation Loss = 0.0106, validation Accuracy = 93.98%, Train Accuracy = 94.24%
# Epoch 47: Validation Loss = 0.0104, validation Accuracy = 94.05%, Train Accuracy = 94.30%
# Epoch 48: Validation Loss = 0.0103, validation Accuracy = 94.05%, Train Accuracy = 94.41%
# Epoch 49: Validation Loss = 0.0101, validation Accuracy = 94.27%, Train Accuracy = 94.48%
# 94.36

# %% [markdown]
# ### lr 0.001

# %%
mlp = MLP(
    layers=[512, 512],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.001,
    optimizer='sgd',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 1: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 2: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 3: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 4: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 5: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 6: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 7: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 8: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 9: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 10: Validation Loss = 0.0900, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 11: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 12: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 13: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 14: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 15: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 16: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 17: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 18: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 19: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 20: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 21: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 22: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 23: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 24: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 25: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 26: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 27: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 28: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 29: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 30: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 31: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 32: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 33: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 34: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 35: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 36: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 37: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 38: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 39: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 40: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 41: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 42: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 43: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 44: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 45: Validation Loss = 0.0899, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 46: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 47: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 48: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# Epoch 49: Validation Loss = 0.0898, validation Accuracy = 11.23%, Train Accuracy = 11.24%
# 11.35

# %% [markdown]
# # Phase 3: Optimization

# %% [markdown]
# ## Nesterov Momentum

# %%
mlp = MLP(
    layers=[64, 64],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='nesterov',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0333, validation Accuracy = 83.97%, Train Accuracy = 83.78%
# Epoch 1: Validation Loss = 0.0109, validation Accuracy = 93.43%, Train Accuracy = 94.25%
# Epoch 2: Validation Loss = 0.0094, validation Accuracy = 94.20%, Train Accuracy = 95.47%
# Epoch 3: Validation Loss = 0.0081, validation Accuracy = 95.17%, Train Accuracy = 96.43%
# Epoch 4: Validation Loss = 0.0073, validation Accuracy = 95.55%, Train Accuracy = 96.95%
# Epoch 5: Validation Loss = 0.0066, validation Accuracy = 96.02%, Train Accuracy = 97.47%
# Epoch 6: Validation Loss = 0.0062, validation Accuracy = 96.18%, Train Accuracy = 97.77%
# Epoch 7: Validation Loss = 0.0062, validation Accuracy = 96.27%, Train Accuracy = 97.92%
# Epoch 8: Validation Loss = 0.0062, validation Accuracy = 96.20%, Train Accuracy = 97.98%
# Epoch 9: Validation Loss = 0.0056, validation Accuracy = 96.55%, Train Accuracy = 98.37%
# Epoch 10: Validation Loss = 0.0065, validation Accuracy = 96.12%, Train Accuracy = 98.09%
# Epoch 11: Validation Loss = 0.0056, validation Accuracy = 96.62%, Train Accuracy = 98.45%
# Epoch 12: Validation Loss = 0.0057, validation Accuracy = 96.42%, Train Accuracy = 98.57%
# Epoch 13: Validation Loss = 0.0056, validation Accuracy = 96.55%, Train Accuracy = 98.78%
# Epoch 14: Validation Loss = 0.0057, validation Accuracy = 96.47%, Train Accuracy = 98.70%
# Epoch 15: Validation Loss = 0.0053, validation Accuracy = 96.82%, Train Accuracy = 99.00%
# Epoch 16: Validation Loss = 0.0055, validation Accuracy = 96.63%, Train Accuracy = 99.02%
# Epoch 17: Validation Loss = 0.0053, validation Accuracy = 96.65%, Train Accuracy = 99.14%
# Epoch 18: Validation Loss = 0.0055, validation Accuracy = 96.62%, Train Accuracy = 99.12%
# Epoch 19: Validation Loss = 0.0054, validation Accuracy = 96.67%, Train Accuracy = 99.13%
# Epoch 20: Validation Loss = 0.0053, validation Accuracy = 96.75%, Train Accuracy = 99.21%
# Epoch 21: Validation Loss = 0.0053, validation Accuracy = 96.60%, Train Accuracy = 99.27%
# Epoch 22: Validation Loss = 0.0052, validation Accuracy = 96.72%, Train Accuracy = 99.24%
# Epoch 23: Validation Loss = 0.0052, validation Accuracy = 96.88%, Train Accuracy = 99.36%
# Epoch 24: Validation Loss = 0.0052, validation Accuracy = 96.72%, Train Accuracy = 99.35%
# Epoch 25: Validation Loss = 0.0051, validation Accuracy = 96.88%, Train Accuracy = 99.37%
# Epoch 26: Validation Loss = 0.0052, validation Accuracy = 96.70%, Train Accuracy = 99.43%
# Epoch 27: Validation Loss = 0.0051, validation Accuracy = 96.88%, Train Accuracy = 99.42%
# Epoch 28: Validation Loss = 0.0052, validation Accuracy = 96.68%, Train Accuracy = 99.46%
# Epoch 29: Validation Loss = 0.0051, validation Accuracy = 96.85%, Train Accuracy = 99.46%
# Epoch 30: Validation Loss = 0.0052, validation Accuracy = 96.65%, Train Accuracy = 99.43%
# Epoch 31: Validation Loss = 0.0050, validation Accuracy = 97.03%, Train Accuracy = 99.50%
# Epoch 32: Validation Loss = 0.0051, validation Accuracy = 96.92%, Train Accuracy = 99.51%
# Epoch 33: Validation Loss = 0.0051, validation Accuracy = 96.82%, Train Accuracy = 99.50%
# Epoch 34: Validation Loss = 0.0050, validation Accuracy = 96.88%, Train Accuracy = 99.54%
# Epoch 35: Validation Loss = 0.0051, validation Accuracy = 96.75%, Train Accuracy = 99.55%
# Epoch 36: Validation Loss = 0.0052, validation Accuracy = 96.75%, Train Accuracy = 99.57%
# Epoch 37: Validation Loss = 0.0050, validation Accuracy = 96.92%, Train Accuracy = 99.57%
# Epoch 38: Validation Loss = 0.0051, validation Accuracy = 96.82%, Train Accuracy = 99.58%
# Epoch 39: Validation Loss = 0.0051, validation Accuracy = 96.83%, Train Accuracy = 99.59%
# Epoch 40: Validation Loss = 0.0050, validation Accuracy = 96.87%, Train Accuracy = 99.60%
# Epoch 41: Validation Loss = 0.0051, validation Accuracy = 96.88%, Train Accuracy = 99.60%
# Epoch 42: Validation Loss = 0.0052, validation Accuracy = 96.75%, Train Accuracy = 99.61%
# Epoch 43: Validation Loss = 0.0051, validation Accuracy = 96.75%, Train Accuracy = 99.62%
# Epoch 44: Validation Loss = 0.0050, validation Accuracy = 96.88%, Train Accuracy = 99.62%
# Epoch 45: Validation Loss = 0.0050, validation Accuracy = 96.92%, Train Accuracy = 99.62%
# Epoch 46: Validation Loss = 0.0051, validation Accuracy = 96.80%, Train Accuracy = 99.63%
# Epoch 47: Validation Loss = 0.0051, validation Accuracy = 96.82%, Train Accuracy = 99.63%
# Epoch 48: Validation Loss = 0.0051, validation Accuracy = 96.88%, Train Accuracy = 99.63%
# Epoch 49: Validation Loss = 0.0051, validation Accuracy = 96.82%, Train Accuracy = 99.64%
# 97.13000000000001

# %% [markdown]
# ## AdaGrad

# %%
mlp = MLP(
    layers=[64, 64],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adagrad',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0274, validation Accuracy = 84.68%, Train Accuracy = 84.35%
# Epoch 1: Validation Loss = 0.0196, validation Accuracy = 87.77%, Train Accuracy = 87.55%
# Epoch 2: Validation Loss = 0.0165, validation Accuracy = 89.53%, Train Accuracy = 89.69%
# Epoch 3: Validation Loss = 0.0157, validation Accuracy = 90.40%, Train Accuracy = 90.42%
# Epoch 4: Validation Loss = 0.0154, validation Accuracy = 90.13%, Train Accuracy = 90.71%
# Epoch 5: Validation Loss = 0.0147, validation Accuracy = 90.83%, Train Accuracy = 91.30%
# Epoch 6: Validation Loss = 0.0146, validation Accuracy = 90.93%, Train Accuracy = 91.56%
# Epoch 7: Validation Loss = 0.0140, validation Accuracy = 91.15%, Train Accuracy = 91.82%
# Epoch 8: Validation Loss = 0.0135, validation Accuracy = 91.50%, Train Accuracy = 92.04%
# Epoch 9: Validation Loss = 0.0135, validation Accuracy = 91.50%, Train Accuracy = 92.32%
# Epoch 10: Validation Loss = 0.0132, validation Accuracy = 91.70%, Train Accuracy = 92.56%
# Epoch 11: Validation Loss = 0.0130, validation Accuracy = 91.87%, Train Accuracy = 92.71%
# Epoch 12: Validation Loss = 0.0131, validation Accuracy = 91.65%, Train Accuracy = 92.72%
# Epoch 13: Validation Loss = 0.0130, validation Accuracy = 91.78%, Train Accuracy = 92.92%
# Epoch 14: Validation Loss = 0.0125, validation Accuracy = 92.00%, Train Accuracy = 93.33%
# Epoch 15: Validation Loss = 0.0124, validation Accuracy = 92.13%, Train Accuracy = 93.47%
# Epoch 16: Validation Loss = 0.0121, validation Accuracy = 92.32%, Train Accuracy = 93.54%
# Epoch 17: Validation Loss = 0.0121, validation Accuracy = 92.53%, Train Accuracy = 93.71%
# Epoch 18: Validation Loss = 0.0119, validation Accuracy = 92.60%, Train Accuracy = 93.90%
# Epoch 19: Validation Loss = 0.0117, validation Accuracy = 92.70%, Train Accuracy = 94.09%
# Epoch 20: Validation Loss = 0.0120, validation Accuracy = 92.65%, Train Accuracy = 94.14%
# Epoch 21: Validation Loss = 0.0116, validation Accuracy = 92.70%, Train Accuracy = 94.19%
# Epoch 22: Validation Loss = 0.0114, validation Accuracy = 92.95%, Train Accuracy = 94.52%
# Epoch 23: Validation Loss = 0.0115, validation Accuracy = 92.78%, Train Accuracy = 94.55%
# Epoch 24: Validation Loss = 0.0113, validation Accuracy = 92.73%, Train Accuracy = 94.67%
# Epoch 25: Validation Loss = 0.0110, validation Accuracy = 93.07%, Train Accuracy = 94.85%
# Epoch 26: Validation Loss = 0.0109, validation Accuracy = 93.25%, Train Accuracy = 94.92%
# Epoch 27: Validation Loss = 0.0109, validation Accuracy = 93.15%, Train Accuracy = 95.00%
# Epoch 28: Validation Loss = 0.0108, validation Accuracy = 93.20%, Train Accuracy = 95.15%
# Epoch 29: Validation Loss = 0.0108, validation Accuracy = 93.02%, Train Accuracy = 95.24%
# Epoch 30: Validation Loss = 0.0108, validation Accuracy = 93.03%, Train Accuracy = 95.28%
# Epoch 31: Validation Loss = 0.0107, validation Accuracy = 93.33%, Train Accuracy = 95.47%
# Epoch 32: Validation Loss = 0.0105, validation Accuracy = 93.45%, Train Accuracy = 95.46%
# Epoch 33: Validation Loss = 0.0104, validation Accuracy = 93.52%, Train Accuracy = 95.52%
# Epoch 34: Validation Loss = 0.0105, validation Accuracy = 93.52%, Train Accuracy = 95.65%
# Epoch 35: Validation Loss = 0.0104, validation Accuracy = 93.48%, Train Accuracy = 95.66%
# Epoch 36: Validation Loss = 0.0103, validation Accuracy = 93.38%, Train Accuracy = 95.75%
# Epoch 37: Validation Loss = 0.0103, validation Accuracy = 93.58%, Train Accuracy = 95.82%
# Epoch 38: Validation Loss = 0.0103, validation Accuracy = 93.48%, Train Accuracy = 95.90%
# Epoch 39: Validation Loss = 0.0103, validation Accuracy = 93.28%, Train Accuracy = 95.94%
# Epoch 40: Validation Loss = 0.0102, validation Accuracy = 93.55%, Train Accuracy = 96.06%
# Epoch 41: Validation Loss = 0.0102, validation Accuracy = 93.70%, Train Accuracy = 95.99%
# Epoch 42: Validation Loss = 0.0101, validation Accuracy = 93.58%, Train Accuracy = 96.16%
# Epoch 43: Validation Loss = 0.0101, validation Accuracy = 93.65%, Train Accuracy = 96.19%
# Epoch 44: Validation Loss = 0.0101, validation Accuracy = 93.58%, Train Accuracy = 96.22%
# Epoch 45: Validation Loss = 0.0100, validation Accuracy = 93.50%, Train Accuracy = 96.32%
# Epoch 46: Validation Loss = 0.0100, validation Accuracy = 93.63%, Train Accuracy = 96.38%
# Epoch 47: Validation Loss = 0.0100, validation Accuracy = 93.60%, Train Accuracy = 96.41%
# Epoch 48: Validation Loss = 0.0098, validation Accuracy = 93.83%, Train Accuracy = 96.51%
# Epoch 49: Validation Loss = 0.0098, validation Accuracy = 93.73%, Train Accuracy = 96.60%
# 94.21000000000001

# %% [markdown]
# ## RMSPop

# %%
mlp = MLP(
    layers=[64,64],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='rmsprop',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.0991, validation Accuracy = 10.22%, Train Accuracy = 10.22%
# C:\Users\Kia\AppData\Local\Temp\ipykernel_8920\4056521755.py:2: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-x))
# Epoch 1: Validation Loss = 0.0944, validation Accuracy = 11.43%, Train Accuracy = 11.40%
# Epoch 2: Validation Loss = 0.1008, validation Accuracy = 17.57%, Train Accuracy = 17.62%
# Epoch 3: Validation Loss = 0.0863, validation Accuracy = 28.87%, Train Accuracy = 29.13%
# Epoch 4: Validation Loss = 0.0641, validation Accuracy = 53.30%, Train Accuracy = 52.74%
# Epoch 5: Validation Loss = 0.0653, validation Accuracy = 50.17%, Train Accuracy = 49.98%
# Epoch 6: Validation Loss = 0.0664, validation Accuracy = 51.15%, Train Accuracy = 51.27%
# Epoch 7: Validation Loss = 0.0561, validation Accuracy = 59.30%, Train Accuracy = 59.48%
# Epoch 8: Validation Loss = 0.0548, validation Accuracy = 62.05%, Train Accuracy = 62.47%
# Epoch 9: Validation Loss = 0.0530, validation Accuracy = 62.50%, Train Accuracy = 62.80%
# Epoch 10: Validation Loss = 0.0525, validation Accuracy = 66.03%, Train Accuracy = 65.98%
# Epoch 11: Validation Loss = 0.0523, validation Accuracy = 65.85%, Train Accuracy = 65.82%
# Epoch 12: Validation Loss = 0.0526, validation Accuracy = 65.35%, Train Accuracy = 65.57%
# Epoch 13: Validation Loss = 0.0490, validation Accuracy = 67.88%, Train Accuracy = 67.82%
# Epoch 14: Validation Loss = 0.0491, validation Accuracy = 64.15%, Train Accuracy = 64.30%
# Epoch 15: Validation Loss = 0.0546, validation Accuracy = 58.75%, Train Accuracy = 59.04%
# Epoch 16: Validation Loss = 0.0473, validation Accuracy = 66.60%, Train Accuracy = 66.81%
# Epoch 17: Validation Loss = 0.0474, validation Accuracy = 69.78%, Train Accuracy = 69.57%
# Epoch 18: Validation Loss = 0.0477, validation Accuracy = 67.70%, Train Accuracy = 67.35%
# Epoch 19: Validation Loss = 0.0451, validation Accuracy = 71.25%, Train Accuracy = 70.73%
# Epoch 20: Validation Loss = 0.0469, validation Accuracy = 68.60%, Train Accuracy = 68.87%
# Epoch 21: Validation Loss = 0.0436, validation Accuracy = 71.05%, Train Accuracy = 71.02%
# Epoch 22: Validation Loss = 0.0456, validation Accuracy = 70.45%, Train Accuracy = 70.45%
# Epoch 23: Validation Loss = 0.0505, validation Accuracy = 67.92%, Train Accuracy = 68.01%
# Epoch 24: Validation Loss = 0.0486, validation Accuracy = 67.90%, Train Accuracy = 68.10%
# Epoch 25: Validation Loss = 0.0477, validation Accuracy = 68.52%, Train Accuracy = 68.00%
# Epoch 26: Validation Loss = 0.0448, validation Accuracy = 69.75%, Train Accuracy = 69.64%
# Epoch 27: Validation Loss = 0.0459, validation Accuracy = 71.97%, Train Accuracy = 71.04%
# Epoch 28: Validation Loss = 0.0456, validation Accuracy = 71.80%, Train Accuracy = 71.47%
# Epoch 29: Validation Loss = 0.0462, validation Accuracy = 69.65%, Train Accuracy = 69.57%
# Epoch 30: Validation Loss = 0.0467, validation Accuracy = 70.32%, Train Accuracy = 69.85%
# Epoch 31: Validation Loss = 0.0556, validation Accuracy = 65.85%, Train Accuracy = 66.09%
# Epoch 32: Validation Loss = 0.0453, validation Accuracy = 70.20%, Train Accuracy = 70.30%
# Epoch 33: Validation Loss = 0.0483, validation Accuracy = 67.88%, Train Accuracy = 67.99%
# Epoch 34: Validation Loss = 0.0497, validation Accuracy = 69.47%, Train Accuracy = 69.70%
# Epoch 35: Validation Loss = 0.0449, validation Accuracy = 70.93%, Train Accuracy = 70.62%
# Epoch 36: Validation Loss = 0.0457, validation Accuracy = 69.47%, Train Accuracy = 69.10%
# Epoch 37: Validation Loss = 0.0466, validation Accuracy = 70.12%, Train Accuracy = 69.78%
# Epoch 38: Validation Loss = 0.0464, validation Accuracy = 70.55%, Train Accuracy = 70.32%
# Epoch 39: Validation Loss = 0.0467, validation Accuracy = 67.47%, Train Accuracy = 67.50%
# Epoch 40: Validation Loss = 0.0457, validation Accuracy = 71.90%, Train Accuracy = 71.62%
# Epoch 41: Validation Loss = 0.0447, validation Accuracy = 71.32%, Train Accuracy = 70.74%
# Epoch 42: Validation Loss = 0.0467, validation Accuracy = 70.77%, Train Accuracy = 70.59%
# Epoch 43: Validation Loss = 0.0469, validation Accuracy = 71.77%, Train Accuracy = 71.71%
# Epoch 44: Validation Loss = 0.0479, validation Accuracy = 69.87%, Train Accuracy = 70.26%
# Epoch 45: Validation Loss = 0.0508, validation Accuracy = 69.88%, Train Accuracy = 70.30%
# Epoch 46: Validation Loss = 0.0476, validation Accuracy = 69.55%, Train Accuracy = 70.25%
# Epoch 47: Validation Loss = 0.0479, validation Accuracy = 69.37%, Train Accuracy = 69.04%
# Epoch 48: Validation Loss = 0.0471, validation Accuracy = 71.35%, Train Accuracy = 71.12%
# Epoch 49: Validation Loss = 0.0482, validation Accuracy = 70.02%, Train Accuracy = 70.04%
# 70.19999999999999

# %% [markdown]
# ## Adam

# %%
mlp = MLP(
    layers=[64, 64],
    activations=['sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adam',
    loss="MSE",
)
mlp.plot_losses()
print(mlp.evaluate(X_test,y_test))
# Out:
# Epoch 0: Validation Loss = 0.1000, validation Accuracy = 10.45%, Train Accuracy = 10.44%
# Epoch 1: Validation Loss = 0.1395, validation Accuracy = 9.03%, Train Accuracy = 9.04%
# Epoch 2: Validation Loss = 0.1000, validation Accuracy = 9.87%, Train Accuracy = 9.87%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 9
#       1 mlp = MLP(
#       2     layers=[64, 64],
#       3     activations=['sigmoid', 'sigmoid', 'sigmoid'],
#    (...)      6     init_method='standard'
#       7 )
# ----> 9 mlp.train(
#      10     X_train, y_train, X_val, y_val,
#      11     epochs=50,
#      12     batch_size=32,
#      13     learning_rate=0.1,
#      14     optimizer='adam',
#      15     loss="MSE",
#      16 )
#      17 mlp.plot_losses()
#      18 print(mlp.evaluate(X_test,y_test))
#
# Cell In[19], line 195, in MLP.train(self, X_train, y_train, X_val, y_val, epochs, batch_size, learning_rate, optimizer, loss)
#     192         batch_loss = cross_entropy(y_batch, activations[-1])
#     194     # Update weights
# --> 195     self.update_weights(grads, learning_rate, optimizer, state, t)
#     196     epoch_train_loss += batch_loss * X_batch.shape[0]  # Weighted by batch size
#     198 # Average training loss for the epoch
#
# Cell In[19], line 111, in MLP.update_weights(self, grads, learning_rate, optimizer, state, t)
#     108 beta1, beta2, epsilon = 0.9, 0.999, 1e-7
#     109 for i in range(len(self.weights)):
#     110     # Weights
# --> 111     state[f'mW{i}'] = beta1 * state[f'mW{i}'] + (1 - beta1) * grads[f'dW{i}']  # Momentum
#     112     state[f'vW{i}'] = beta2 * state[f'vW{i}'] + (1 - beta2) * (grads[f'dW{i}'] ** 2)  # RMSProp
#     113     mW_corr = state[f'mW{i}'] / (1 - beta1 ** t)  # Bias correction
#
# KeyboardInterrupt:

# %% [markdown]
# # Phase4: Vanishing Gradient and Weight Initialization

# %% [markdown]
# ## Standard init and sigmoid

# %%
mlp = MLP(
    layers=[256,256,256,256,256,256],
    activations=['sigmoid', 'sigmoid', 'sigmoid','sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adam',
    loss="MSE",
)
mlp.plot_losses()
mlp.plot_weights()
print(mlp.evaluate(X_test,y_test))
# Out:
# Exception ignored in: 'zmq.backend.cython._zmq.Frame.__del__'
# Traceback (most recent call last):
#   File "_zmq.py", line 160, in zmq.backend.cython._zmq._check_rc
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       1 mlp = MLP(
#       2     layers=[256,256,256,256,256,256],
#       3     activations=['sigmoid', 'sigmoid', 'sigmoid','sigmoid', 'sigmoid', 'sigmoid'],
#    (...)
#       6     init_method='standard'
#       7 )
# ----> 9 mlp.train(
#      10     X_train, y_train, X_val, y_val,
#      11     epochs=50,
#      12     batch_size=32,
#      13     learning_rate=0.1,
#      14     optimizer='adam',
#      15     loss="MSE",
#      16 )
#      17 mlp.plot_losses()
#      18 mlp.plot_weights()
#
# Cell In[4], line 195, in MLP.train(self, X_train, y_train, X_val, y_val, epochs, batch_size, learning_rate, optimizer, loss)
#     192         batch_loss = cross_entropy(y_batch, activations[-1])
#     194     # Update weights
# --> 195     self.update_weights(grads, learning_rate, optimizer, state, t)
#     196     epoch_train_loss += batch_loss * X_batch.shape[0]  # Weighted by batch size
#     198 # Average training loss for the epoch
#
# Cell In[4], line 117, in MLP.update_weights(self, grads, learning_rate, optimizer, state, t)
#     115 self.weights[i] -= learning_rate * mW_corr / (np.sqrt(vW_corr) + epsilon)
#     116 # Biases (fixed)
# --> 117 state[f'mb{i}'] = beta1 * state[f'mb{i}'] + (1 - beta1) * grads[f'db{i}']
#     118 state[f'vb{i}'] = beta2 * state[f'vb{i}'] + (1 - beta2) * (grads[f'db{i}'] ** 2)
#     119 mb_corr = state[f'mb{i}'] / (1 - beta1 ** t)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Xavier and sigmoid

# %%
mlp = MLP(
    layers=[256,256,256,256,256,256],
    activations=['sigmoid', 'sigmoid', 'sigmoid','sigmoid', 'sigmoid', 'sigmoid'],
    input_size=784,
    output_size=10,
    init_method='xavier'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adam',
    loss="MSE",
)
mlp.plot_losses()
mlp.plot_weights()
print(mlp.evaluate(X_test,y_test))

# %% [markdown]
# ## Xavier and Relu

# %%
mlp = MLP(
    layers=[256,256,256,256,256,256],
    activations=['relu', 'relu', 'relu','relu', 'relu', 'relu'],
    input_size=784,
    output_size=10,
    init_method='standard'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adam',
    loss="MSE",
)
mlp.plot_losses()
mlp.plot_weights()
print(mlp.evaluate(X_test,y_test))

# %% [markdown]
# # Phase 5: SofttMax + Cross-Entropy

# %%
mlp = MLP(
    layers=[256,256,256,256,256,256],
    activations=['relu', 'relu', 'relu','relu', 'relu', 'softmax'],
    input_size=784,
    output_size=10,
    init_method='xavier'
)

mlp.train(
    X_train, y_train, X_val, y_val,
    epochs=50,
    batch_size=32,
    learning_rate=0.1,
    optimizer='adam',
    loss="crossentropy",
)
mlp.plot_losses()
mlp.plot_weights()
print(mlp.evaluate(X_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 9
#       1 mlp = MLP(
#       2     layers=[256,256,256,256,256,256],
#       3     activations=['relu', 'relu', 'relu','relu', 'relu', 'softmax'],
#    (...)
#       6     init_method='xavier'
#       7 )
# ----> 9 mlp.train(
#      10     X_train, y_train, X_val, y_val,
#      11     epochs=50,
#      12     batch_size=32,
#      13     learning_rate=0.1,
#      14     optimizer='adam',
#      15     loss="crossentropy",
#      16 )
#      17 mlp.plot_losses()
#      18 mlp.plot_weights()
#
# Cell In[4], line 191, in MLP.train(self, X_train, y_train, X_val, y_val, epochs, batch_size, learning_rate, optimizer, loss)
#     189     batch_loss = mean_squared_error(y_batch, activations[-1])
#     190 else:
# --> 191     grads=self.backward_crossentropy(X_batch, y_batch, activations, pre_activations)
#     192     batch_loss = cross_entropy(y_batch, activations[-1])
#     194 # Update weights
#
# Cell In[4], line 97, in MLP.backward_crossentropy(self, X, y, activations, pre_activations)
#      94     grads[f'db{l}'] = np.sum(delta, axis=0, keepdims=True) / X.shape[0]
#      96     if l > 0:  # Propagate delta to previous layer
# ---> 97         delta = np.dot(delta, self.weights[l].T) * activation_derivative(pre_activations[l-1], self.activations[l-1])
#      99 return grads
#
# TypeError: unsupported operand type(s) for *: 'float' and 'NoneType'

# %% [markdown]
# # Phase 6: PCA

# %%
pca = PCA()
pca.fit(X_train)
cumulative_variance = pca.explained_variance_ratio_.cumsum()

plt.figure(figsize=(10, 6))
# plt.plot(range(1, n_components + 1), cumulative_variance, marker='o')
plt.plot(range(1, 101), cumulative_variance[:100], marker='o') 
plt.title("Cumulative Variance Explained by PCA Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance Explained")
plt.axhline(y=0.80, color='r', linestyle='--')
plt.axhline(y=0.90, color='r', linestyle='--')  
plt.axhline(y=0.70, color='r', linestyle='--')  


plt.grid()
plt.show()

best_n_components70 = np.argmax(cumulative_variance >= 0.80) + 1
best_n_components80 = np.argmax(cumulative_variance >= 0.80) + 1
best_n_components90 = np.argmax(cumulative_variance >= 0.80) + 1
print(f"Number of components to explain at least 70% 80% 90% variance: {best_n_components70,best_n_components80,best_n_components90}")
